# %%
from io import StringIO

import matplotlib.pyplot as plt
from scipy.io import arff
import seaborn as sns
from loguru import logger
import yaml

from datetime import datetime
import polars as pl
import pandas as pd
import numpy as np
import sys
import os
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# MODEL
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import (
    LabelEncoder, 
    StandardScaler,
    label_binarize
)
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    accuracy_score,
    precision_recall_fscore_support,
    balanced_accuracy_score,
    roc_auc_score,
    roc_curve
)

# Save variables for model
import joblib
import json

import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# PERSONAL FUNCTIONS
from utils import *
from models.main import *
from models.optimizer import ViterbiLiteDecoder

from functions.windows import create_feature_windows # creación de ventanas e ingenieria de características
from functions.multimodal import create_multimodal_windows_robust

# %%
dict_preds = {
    'Eat':      {'y': [], 'y_pred': [], 'y_pred_probs': []},
    'Write':    {'y': [], 'y_pred': [], 'y_pred_probs': []},
    # 'Others':    {'y': [], 'y_pred': [], 'y_pred_probs': []} ,
    'Walk':     {'y': [], 'y_pred': [], 'y_pred_probs': []},
    'Sit':      {'y': [], 'y_pred': [], 'y_pred_probs': []},
    'Type':     {'y': [], 'y_pred': [], 'y_pred_probs': []},
}

# %%
dic_result = {
    'Eat':      {'Accuracy' : [], 'F1-score': [], 'Precision': [], 'Recall': []}, 
    'Write':    {'Accuracy' : [], 'F1-score': [], 'Precision': [], 'Recall': []},
    'Walk':     {'Accuracy' : [], 'F1-score': [], 'Precision': [], 'Recall': []},
    'Sit':      {'Accuracy' : [], 'F1-score': [], 'Precision': [], 'Recall': []},
    # 'Others':    {'Accuracy' : [], 'F1-score': [], 'Precision': [], 'Recall': []},
    'Type':     {'Accuracy' : [], 'F1-score': [], 'Precision': [], 'Recall': []}
}

# %%
loaded = tf.saved_model.load(r"..\cnn_tcn\model_with_stand_in_others\saved_model")
infer = loaded.signatures["serving_default"]
label_encoder = joblib.load(r'..\cnn_tcn\model_with_stand_in_others\label_encoder.joblib')

# %%
path_base = r"..\data\real-data"
archive_date = [archive for archive in os.listdir(path_base) if '.json' not in archive]


for data in archive_date:
    path_data = os.path.join(path_base, data)
    file_data = os.listdir(path_data)

    target = data.split('-')[0].title()
        
    if target == 'Stand' or target == 'Sensor' or target == 'Day': #or target == "Write":
        continue
    
    for file in file_data:

        file_path = os.path.join(path_data, file)
        
        with open(file_path, 'rb') as file:
            data = json.load(file)

        gyro_df = data['gyro']
        accel_df = data['accel']

        accel_temp = pl.DataFrame(accel_df)
        gyro_temp = pl.DataFrame(gyro_df)

        
        accel_temp = accel_temp.with_columns(pl.lit('A').alias('Usuario'))
        gyro_temp  = gyro_temp.with_columns(pl.lit('A').alias('Usuario'))

        accel_temp = accel_temp.with_columns(pl.lit(target).alias('gt'))
        gyro_temp = gyro_temp.with_columns(pl.lit(target).alias('gt'))

        df_accel = normalize_columns(accel_temp,
                            user_col_name  = "Usuario", 
                            timestamp_col_name = "timestamp", 
                            label_col_name = "gt", 
                            x_col_name = "x", 
                            y_col_name = "y", 
                            z_col_name = "z"
                        )

        df_gyro = normalize_columns(gyro_temp, 
                            user_col_name  = "Usuario", 
                            timestamp_col_name = "timestamp", 
                            label_col_name = "gt", 
                            x_col_name = "x", 
                            y_col_name = "y", 
                            z_col_name = "z"
                        )
        
        df_accel = convert_timestamp(df_accel)
        df_gyro = convert_timestamp(df_gyro)

        X_all, y_all, subjects_all, metadata_all = create_multimodal_windows_robust(
            df_accel = df_accel, 
            # df_gyro = df_gyro,
            window_seconds=5,
            overlap_percent=50,
            sampling_rate=20,
            target_timesteps=100,
            min_data_threshold=0.8,  # 80% mínimo de datos
            max_gap_seconds=1.0      # Máximo 1 segundo de gap
        )

        X_tensor = tf.constant(X_all, dtype=tf.float32)
        y_pred = infer(X_tensor)
        y_all = label_encoder.transform(y_all)

        # Ejemplo: y_pred con probabilidades
        y_pred_probs = list(y_pred.values())[0].numpy()

        # Convertir a clases predichas (índice del máximo)
        y_pred_classes = np.argmax(y_pred_probs, axis=1)


        # Comparar con y_real (asegúrate de que y_real tenga etiquetas 0..N-1)
        acc = accuracy_score(y_all, y_pred_classes)
        
        precision, recall, f1, _ = precision_recall_fscore_support(
                y_all, y_pred_classes, average='macro', zero_division=0
            )
        
        dic_result[target]['Accuracy'].append(acc*100)
        dic_result[target]['F1-score'].append(f1*100)
        dic_result[target]['Precision'].append(precision*100)
        dic_result[target]['Recall'].append(recall*100)

        dict_preds[target]['y'].extend(y_all)
        dict_preds[target]['y_pred'].extend(y_pred_classes)
# Out:
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 6531 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Eat:
#    Accel: 6531 muestras
#    ✅ Creadas 59 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 59
#   Ventanas creadas: 59
#   Ventanas con gyro: 0
#   Ventanas solo accel: 59
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (59, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 59
#   Usuarios únicos: 1
#   Actividades: ['Eat']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 6488 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Eat:
#    Accel: 6488 muestras
#    ✅ Creadas 59 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 59
#   Ventanas creadas: 59
#   Ventanas con gyro: 0
#   Ventanas solo accel: 59
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (59, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 59
#   Usuarios únicos: 1
#   Actividades: ['Eat']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 18244 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Eat:
#    Accel: 18244 muestras
#    ✅ Creadas 271 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 271
#   Ventanas creadas: 271
#   Ventanas con gyro: 0
#   Ventanas solo accel: 271
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (271, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 271
#   Usuarios únicos: 1
#   Actividades: ['Eat']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1784 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Eat:
#    Accel: 1784 muestras
#    ✅ Creadas 26 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 26
#   Ventanas creadas: 26
#   Ventanas con gyro: 0
#   Ventanas solo accel: 26
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (26, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 26
#   Usuarios únicos: 1
#   Actividades: ['Eat']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 3693 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Eat:
#    Accel: 3693 muestras
#    ✅ Creadas 57 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 57
#   Ventanas creadas: 57
#   Ventanas con gyro: 0
#   Ventanas solo accel: 57
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (57, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 57
#   Usuarios únicos: 1
#   Actividades: ['Eat']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 2498 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 2498 muestras
#    ✅ Creadas 34 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 34
#   Ventanas creadas: 34
#   Ventanas con gyro: 0
#   Ventanas solo accel: 34
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (34, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 34
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 2119 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 2119 muestras
#    ✅ Creadas 28 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 28
#   Ventanas creadas: 28
#   Ventanas con gyro: 0
#   Ventanas solo accel: 28
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (28, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 28
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1990 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1990 muestras
#    ✅ Creadas 29 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 29
#   Ventanas creadas: 29
#   Ventanas con gyro: 0
#   Ventanas solo accel: 29
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (29, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 29
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1897 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1897 muestras
#    ✅ Creadas 29 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 29
#   Ventanas creadas: 29
#   Ventanas con gyro: 0
#   Ventanas solo accel: 29
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (29, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 29
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1708 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1708 muestras
#    ✅ Creadas 26 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 26
#   Ventanas creadas: 26
#   Ventanas con gyro: 0
#   Ventanas solo accel: 26
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (26, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 26
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1884 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1884 muestras
#    ✅ Creadas 28 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 28
#   Ventanas creadas: 28
#   Ventanas con gyro: 0
#   Ventanas solo accel: 28
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (28, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 28
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1850 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1850 muestras
#    ✅ Creadas 28 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 28
#   Ventanas creadas: 28
#   Ventanas con gyro: 0
#   Ventanas solo accel: 28
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (28, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 28
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 2419 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 2419 muestras
#    ✅ Creadas 37 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 37
#   Ventanas creadas: 37
#   Ventanas con gyro: 0
#   Ventanas solo accel: 37
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (37, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 37
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1884 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1884 muestras
#    ✅ Creadas 28 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 28
#   Ventanas creadas: 28
#   Ventanas con gyro: 0
#   Ventanas solo accel: 28
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (28, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 28
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 2203 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 2203 muestras
#    ✅ Creadas 30 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 33
#   Ventanas creadas: 30
#   Ventanas con gyro: 0
#   Ventanas solo accel: 30
#   Tasa de éxito: 90.9%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (30, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 30
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1559 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1559 muestras
#    ✅ Creadas 23 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 23
#   Ventanas creadas: 23
#   Ventanas con gyro: 0
#   Ventanas solo accel: 23
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (23, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 23
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1509 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1509 muestras
#    ✅ Creadas 23 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 23
#   Ventanas creadas: 23
#   Ventanas con gyro: 0
#   Ventanas solo accel: 23
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (23, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 23
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1860 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1860 muestras
#    ✅ Creadas 28 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 28
#   Ventanas creadas: 28
#   Ventanas con gyro: 0
#   Ventanas solo accel: 28
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (28, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 28
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1431 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1431 muestras
#    ✅ Creadas 21 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 21
#   Ventanas creadas: 21
#   Ventanas con gyro: 0
#   Ventanas solo accel: 21
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (21, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 21
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1485 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1485 muestras
#    ✅ Creadas 22 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 22
#   Ventanas creadas: 22
#   Ventanas con gyro: 0
#   Ventanas solo accel: 22
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (22, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 22
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1961 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1961 muestras
#    ✅ Creadas 30 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 30
#   Ventanas creadas: 30
#   Ventanas con gyro: 0
#   Ventanas solo accel: 30
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (30, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 30
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1282 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1282 muestras
#    ✅ Creadas 19 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 19
#   Ventanas creadas: 19
#   Ventanas con gyro: 0
#   Ventanas solo accel: 19
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (19, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 19
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1459 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Sit:
#    Accel: 1459 muestras
#    ✅ Creadas 22 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 22
#   Ventanas creadas: 22
#   Ventanas con gyro: 0
#   Ventanas solo accel: 22
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (22, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 22
#   Usuarios únicos: 1
#   Actividades: ['Sit']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1880 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1880 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1612 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1612 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1583 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1583 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1608 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1608 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1790 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1790 muestras
#    ✅ Creadas 23 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 23
#   Ventanas creadas: 23
#   Ventanas con gyro: 0
#   Ventanas solo accel: 23
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (23, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 23
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1583 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1583 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1582 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1582 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1624 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1624 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1558 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1558 muestras
#    ✅ Creadas 23 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 23
#   Ventanas creadas: 23
#   Ventanas con gyro: 0
#   Ventanas solo accel: 23
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (23, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 23
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1624 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1624 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1759 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1759 muestras
#    ✅ Creadas 26 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 26
#   Ventanas creadas: 26
#   Ventanas con gyro: 0
#   Ventanas solo accel: 26
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (26, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 26
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1659 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1659 muestras
#    ✅ Creadas 25 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 25
#   Ventanas creadas: 25
#   Ventanas con gyro: 0
#   Ventanas solo accel: 25
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (25, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 25
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1534 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1534 muestras
#    ✅ Creadas 23 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 23
#   Ventanas creadas: 23
#   Ventanas con gyro: 0
#   Ventanas solo accel: 23
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (23, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 23
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1634 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1634 muestras
#    ✅ Creadas 25 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 25
#   Ventanas creadas: 25
#   Ventanas con gyro: 0
#   Ventanas solo accel: 25
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (25, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 25
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1609 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1609 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1722 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1722 muestras
#    ✅ Creadas 26 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 26
#   Ventanas creadas: 26
#   Ventanas con gyro: 0
#   Ventanas solo accel: 26
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (26, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 26
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1586 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1586 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1713 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1713 muestras
#    ✅ Creadas 26 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 26
#   Ventanas creadas: 26
#   Ventanas con gyro: 0
#   Ventanas solo accel: 26
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (26, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 26
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1731 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1731 muestras
#    ✅ Creadas 26 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 26
#   Ventanas creadas: 26
#   Ventanas con gyro: 0
#   Ventanas solo accel: 26
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (26, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 26
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1610 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1610 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1609 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1609 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1707 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Type:
#    Accel: 1707 muestras
#    ✅ Creadas 26 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 26
#   Ventanas creadas: 26
#   Ventanas con gyro: 0
#   Ventanas solo accel: 26
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (26, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 26
#   Usuarios únicos: 1
#   Actividades: ['Type']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 4199 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Walk:
#    Accel: 4199 muestras
#    ✅ Creadas 63 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 63
#   Ventanas creadas: 63
#   Ventanas con gyro: 0
#   Ventanas solo accel: 63
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (63, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 63
#   Usuarios únicos: 1
#   Actividades: ['Walk']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 34981 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Walk:
#    Accel: 34981 muestras
#    ✅ Creadas 547 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 547
#   Ventanas creadas: 547
#   Ventanas con gyro: 0
#   Ventanas solo accel: 547
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (547, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 547
#   Usuarios únicos: 1
#   Actividades: ['Walk']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 679 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Walk:
#    Accel: 679 muestras
#    ✅ Creadas 9 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 9
#   Ventanas creadas: 9
#   Ventanas con gyro: 0
#   Ventanas solo accel: 9
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (9, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 9
#   Usuarios únicos: 1
#   Actividades: ['Walk']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1672 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 1672 muestras
#    ✅ Creadas 25 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 25
#   Ventanas creadas: 25
#   Ventanas con gyro: 0
#   Ventanas solo accel: 25
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (25, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 25
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1812 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 1812 muestras
#    ✅ Creadas 27 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 27
#   Ventanas creadas: 27
#   Ventanas con gyro: 0
#   Ventanas solo accel: 27
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (27, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 27
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1960 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 1960 muestras
#    ✅ Creadas 30 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 30
#   Ventanas creadas: 30
#   Ventanas con gyro: 0
#   Ventanas solo accel: 30
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (30, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 30
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1820 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 1820 muestras
#    ✅ Creadas 27 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 27
#   Ventanas creadas: 27
#   Ventanas con gyro: 0
#   Ventanas solo accel: 27
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (27, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 27
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1860 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 1860 muestras
#    ✅ Creadas 27 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 27
#   Ventanas creadas: 27
#   Ventanas con gyro: 0
#   Ventanas solo accel: 27
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (27, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 27
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1784 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 1784 muestras
#    ✅ Creadas 27 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 27
#   Ventanas creadas: 27
#   Ventanas con gyro: 0
#   Ventanas solo accel: 27
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (27, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 27
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1708 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 1708 muestras
#    ✅ Creadas 25 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 25
#   Ventanas creadas: 25
#   Ventanas con gyro: 0
#   Ventanas solo accel: 25
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (25, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 25
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 1583 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 1583 muestras
#    ✅ Creadas 24 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 24
#   Ventanas creadas: 24
#   Ventanas con gyro: 0
#   Ventanas solo accel: 24
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (24, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 24
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 2010 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 2010 muestras
#    ✅ Creadas 30 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 30
#   Ventanas creadas: 30
#   Ventanas con gyro: 0
#   Ventanas solo accel: 30
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (30, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 30
#   Usuarios únicos: 1
#   Actividades: ['Write']
# 🔧 CONFIGURACIÓN MONOMODAL (Solo Accel):
#   Duración: 5s
#   Timesteps objetivo: 100
#   Canales objetivo: 3
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Tolerancia sincronización: 50ms
#   ACCEL preparado: 2160 muestras
#
# 📏 PARÁMETROS TEMPORALES:
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
#
# 👤 Usuario A, Write:
#    Accel: 2160 muestras
#    ✅ Creadas 33 ventanas válidas
#
# 📊 RESUMEN MULTIMODAL:
#   Ventanas intentadas: 33
#   Ventanas creadas: 33
#   Ventanas con gyro: 0
#   Ventanas solo accel: 33
#   Tasa de éxito: 100.0%
#
# ✅ RESULTADO FINAL MULTIMODAL:
#   Forma de X: (33, 100, 3) (samples, timesteps, channels)
#   Canales: 3 (solo accel_xyz)
#   Total ventanas: 33
#   Usuarios únicos: 1
#   Actividades: ['Write']

# %%
from sklearn.metrics import classification_report

y_true_global = []
y_pred_global = []
y_pred_probs_global = []

for activity in dict_preds.keys():
    y_true_global.extend(dict_preds[activity]['y'])
    y_pred_global.extend(dict_preds[activity]['y_pred'])
    y_pred_probs_global.extend(dict_preds[activity]['y_pred_probs'])

labels = np.unique(y_true_global)  # clases presentes en los datos
target_names = label_encoder.inverse_transform(labels)

print(classification_report(
    y_true_global, y_pred_global,
    labels=labels,
    target_names=target_names
))
# Out:
#               precision    recall  f1-score   support
#
#          Eat       0.70      0.64      0.67       472
#          Sit       0.75      0.82      0.79       485
#         Type       0.95      0.88      0.92       537
#         Walk       0.98      0.94      0.96       619
#        Write       0.99      0.98      0.98       275
#
#    micro avg       0.87      0.85      0.86      2388
#    macro avg       0.87      0.85      0.86      2388
# weighted avg       0.87      0.85      0.86      2388

# %%
acc_global = accuracy_score(y_true_global, y_pred_global)
print(f'Accuracy global: {acc_global*100:.2f}%')
# Out:
# Accuracy global: 84.63%
