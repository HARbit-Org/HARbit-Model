# %%
from io import StringIO

import matplotlib.pyplot as plt
from scipy.io import arff
import seaborn as sns
from loguru import logger
import yaml

from datetime import datetime
import polars as pl
import pandas as pd
import numpy as np
import sys
import os
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# MODEL
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import (
    LabelEncoder, 
    StandardScaler,
    label_binarize
)
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    accuracy_score,
    precision_recall_fscore_support,
    balanced_accuracy_score,
    roc_auc_score,
    roc_curve
)

# Save variables for model
import joblib

# PERSONAL FUNCTIONS
from utils import *
from models.main import *
# from functions.windows import create_feature_windows # creación de ventanas e ingenieria de características

# %%
with open(r'F:\UPC\Tesis\HARbit-Model\src\config\activities.yaml', 'r') as file:
    config = yaml.safe_load(file)['config']

# %%
activities_ = config['labels']
cluster_ = config['clusters']

# %%
def create_raw_windows_250_timesteps_robust(df, window_seconds=5, overlap_percent=50, 
                                           sampling_rate=20, target_timesteps=250,
                                           min_data_threshold=0.5, max_gap_seconds=1.0):
    """
    Versión ROBUSTA: Crea ventanas basadas en TIEMPO REAL con validación mejorada
    
    Args:
        df: DataFrame con datos de sensores (Polars o Pandas)
        window_seconds: Duración de la ventana en segundos (default: 5)
        overlap_percent: Porcentaje de solapamiento (default: 50)
        sampling_rate: Frecuencia de muestreo en Hz (default: 20)
        target_timesteps: Número objetivo de timesteps por ventana (default: 250)
        min_data_threshold: Umbral mínimo de datos válidos (0.5 = 50%)
        max_gap_seconds: Máximo gap permitido en segundos (1.0s)
        
    Returns:
        X: Array con forma (n_windows, 250, 3) - datos de ventanas
        y: Array con etiquetas de actividad
        subjects: Array con IDs de usuario
        metadata: DataFrame con información de las ventanas
    """
    
    print(f"🔧 Configuración de ventanas RAW ROBUSTA:")
    print(f"  Duración: {window_seconds}s")
    print(f"  Timesteps objetivo: {target_timesteps}")
    print(f"  Frecuencia de muestreo: {sampling_rate}Hz")
    print(f"  Solapamiento: {overlap_percent}%")
    print(f"  Umbral mínimo de datos: {min_data_threshold*100:.1f}%")
    print(f"  Máximo gap permitido: {max_gap_seconds}s")
    
    # Convertir a pandas si es necesario
    if hasattr(df, 'to_pandas'):
        df_pd = df.to_pandas()
    else:
        df_pd = df.copy()
    
    # Asegurar que Timestamp es datetime
    if df_pd['Timestamp'].dtype == 'object':
        df_pd['Timestamp'] = pd.to_datetime(df_pd['Timestamp'])
    elif df_pd['Timestamp'].dtype == 'int64':
        df_pd['Timestamp'] = pd.to_datetime(df_pd['Timestamp'])
    
    # Calcular parámetros de tiempo
    window_duration_ns = int(window_seconds * 1e9)
    step_duration_ns = int(window_duration_ns * (100 - overlap_percent) / 100)
    
    print(f"  Duración de ventana: {window_seconds}s")
    print(f"  Paso entre ventanas: {step_duration_ns / 1e9:.2f}s")
    
    # Listas para almacenar resultados
    X_windows = []
    y_labels = []
    subjects_list = []
    metadata_list = []
    
    total_windows_attempted = 0
    total_windows_created = 0
    
    # Procesar por usuario y actividad
    for (user_id, activity), group in df_pd.groupby(['Subject-id', 'Activity Label']):
        
        # Ordenar por timestamp y limpiar datos
        group = group.sort_values('Timestamp').reset_index(drop=True)
        group = group.dropna(subset=['X', 'Y', 'Z', 'Timestamp'])
        
        if len(group) < window_seconds * sampling_rate:
            print(f"⚠️ Usuario {user_id}, Actividad {activity}: Muy pocos datos ({len(group)} muestras)")
            continue
        
        # Convertir timestamps a nanosegundos
        if group['Timestamp'].dtype.name.startswith('datetime'):
            timestamps_ns = group['Timestamp'].astype('int64')
        else:
            timestamps_ns = group['Timestamp'].values
        
        print(f"👤 Usuario {user_id}, Actividad {activity}: {len(group)} muestras")
        
        # Obtener rango temporal
        start_time_ns = timestamps_ns.min()
        end_time_ns = timestamps_ns.max()
        total_duration_s = (end_time_ns - start_time_ns) / 1e9
        
        print(f"   Duración total: {total_duration_s:.1f}s")
        
        # Detectar y reportar gaps grandes
        time_diffs = np.diff(timestamps_ns) / 1e9  # Convertir a segundos
        large_gaps = time_diffs > max_gap_seconds
        if np.any(large_gaps):
            n_gaps = np.sum(large_gaps)
            max_gap = np.max(time_diffs)
            print(f"   ⚠️ Detectados {n_gaps} gaps > {max_gap_seconds}s (máximo: {max_gap:.1f}s)")
        
        # Crear ventanas deslizantes
        window_count = 0
        current_start_ns = start_time_ns
        
        while current_start_ns + window_duration_ns <= end_time_ns:
            total_windows_attempted += 1
            current_end_ns = current_start_ns + window_duration_ns
            
            # Filtrar datos en esta ventana temporal
            window_mask = (
                (timestamps_ns >= current_start_ns) & 
                (timestamps_ns < current_end_ns)
            )
            window_data_df = group[window_mask]
            
            # Validación de ventana
            is_valid, validation_info = validate_window_data(
                window_data_df, 
                window_seconds, 
                sampling_rate, 
                min_data_threshold,
                max_gap_seconds
            )
            
            if is_valid:
                # Extraer datos de sensores
                sensor_data = window_data_df[['X', 'Y', 'Z']].values
                window_timestamps = window_data_df['Timestamp'].values
                
                try:
                    # Redimensionar/interpolar a target_timesteps
                    resampled_window = resample_window_robust(
                        sensor_data, window_timestamps, target_timesteps, window_seconds
                    )
                    
                    # Verificar calidad final
                    if is_window_quality_good(resampled_window):
                        # Guardar datos
                        X_windows.append(resampled_window)
                        y_labels.append(activity)
                        subjects_list.append(user_id)
                        
                        # Metadata extendida
                        metadata_list.append({
                            'Subject-id': user_id,
                            'Activity Label': activity,
                            'window_start': pd.to_datetime(current_start_ns),
                            'window_end': pd.to_datetime(current_end_ns),
                            'original_samples': len(window_data_df),
                            'resampled_timesteps': target_timesteps,
                            'window_idx': window_count,
                            'actual_duration_s': window_seconds,
                            'data_coverage': validation_info['data_coverage'],
                            'max_gap_s': validation_info['max_gap'],
                            'sampling_rate_actual': validation_info['actual_rate']
                        })
                        
                        window_count += 1
                        total_windows_created += 1
                    else:
                        print(f"   ❌ Ventana {window_count}: Calidad de datos insuficiente después de interpolación")
                
                except Exception as e:
                    print(f"   ❌ Ventana {window_count}: Error en interpolación - {str(e)}")
            
            else:
                # No mostrar warning para cada ventana inválida, solo resumen
                pass
            
            # Mover al siguiente inicio de ventana
            current_start_ns += step_duration_ns
        
        print(f"  ✅ Creadas {window_count} ventanas válidas")
    
    # Resumen final
    print(f"\n📊 RESUMEN DE VALIDACIÓN:")
    print(f"  Ventanas intentadas: {total_windows_attempted}")
    print(f"  Ventanas creadas: {total_windows_created}")
    print(f"  Tasa de éxito: {(total_windows_created/total_windows_attempted)*100:.1f}%")
    
    # Convertir a arrays numpy
    if len(X_windows) > 0:
        X = np.array(X_windows)
        y = np.array(y_labels)
        subjects = np.array(subjects_list)
        metadata_df = pd.DataFrame(metadata_list)
        
        print(f"\n📊 RESULTADO FINAL (ROBUSTO):")
        print(f"  Forma de X: {X.shape}")
        print(f"  Forma de y: {y.shape}")
        print(f"  Total ventanas: {len(X)}")
        print(f"  Usuarios únicos: {len(np.unique(subjects))}")
        print(f"  Actividades únicas: {sorted(np.unique(y))}")
        
        return X, y, subjects, metadata_df
    
    else:
        print("❌ No se crearon ventanas válidas")
        return None, None, None, None


def validate_window_data(window_data_df, window_seconds, sampling_rate, 
                        min_data_threshold, max_gap_seconds):
    """
    Valida si una ventana de datos es aceptable
    
    Returns:
        bool: True si la ventana es válida
        dict: Información de validación
    """
    if len(window_data_df) == 0:
        return False, {'reason': 'empty', 'data_coverage': 0, 'max_gap': float('inf'), 'actual_rate': 0}
    
    # Calcular cobertura de datos esperada
    expected_samples = window_seconds * sampling_rate
    actual_samples = len(window_data_df)
    data_coverage = actual_samples / expected_samples
    
    # Si hay muy pocos datos
    if data_coverage < min_data_threshold:
        return False, {
            'reason': 'insufficient_data', 
            'data_coverage': data_coverage,
            'max_gap': float('inf'),
            'actual_rate': 0
        }
    
    # Calcular gaps en los datos
    if len(window_data_df) > 1:
        timestamps = pd.to_datetime(window_data_df['Timestamp'])
        time_diffs = timestamps.diff().dt.total_seconds().fillna(0)
        max_gap = time_diffs.max()
        actual_rate = len(window_data_df) / (timestamps.max() - timestamps.min()).total_seconds()
    else:
        max_gap = 0
        actual_rate = sampling_rate
    
    # Si hay gaps muy grandes
    if max_gap > max_gap_seconds:
        return False, {
            'reason': 'large_gap', 
            'data_coverage': data_coverage,
            'max_gap': max_gap,
            'actual_rate': actual_rate
        }
    
    # Verificar que no hay valores NaN o infinitos en los sensores
    sensor_data = window_data_df[['X', 'Y', 'Z']].values
    if np.any(np.isnan(sensor_data)) or np.any(np.isinf(sensor_data)):
        return False, {
            'reason': 'invalid_values',
            'data_coverage': data_coverage,
            'max_gap': max_gap,
            'actual_rate': actual_rate
        }
    
    return True, {
        'reason': 'valid',
        'data_coverage': data_coverage,
        'max_gap': max_gap,
        'actual_rate': actual_rate
    }


def resample_window_robust(sensor_data, timestamps, target_timesteps, window_seconds):
    """
    Versión robusta de remuestreo con múltiples estrategias
    """
    from scipy.interpolate import interp1d
    from scipy import signal
    
    if len(sensor_data) == 0:
        return np.zeros((target_timesteps, 3))
    
    original_timesteps = len(sensor_data)
    
    if original_timesteps == target_timesteps:
        return sensor_data.copy()
    
    if original_timesteps == 1:
        return np.tile(sensor_data[0], (target_timesteps, 1))
    
    try:
        # Estrategia 1: Interpolación temporal precisa
        if hasattr(timestamps[0], 'timestamp'):
            time_seconds = np.array([t.timestamp() for t in timestamps])
        elif isinstance(timestamps[0], pd.Timestamp):
            time_seconds = np.array([t.timestamp() for t in timestamps])
        else:
            time_seconds = timestamps.astype('int64') / 1e9
        
        # Normalizar tiempos
        time_min = time_seconds.min()
        time_max = time_seconds.max()
        
        if time_max > time_min:
            relative_times = (time_seconds - time_min) / (time_max - time_min)
        else:
            relative_times = np.linspace(0, 1, len(time_seconds))
        
        # Crear tiempos objetivo uniformes
        target_times = np.linspace(0, 1, target_timesteps)
        
        # Interpolar cada eje
        resampled_data = np.zeros((target_timesteps, 3))
        
        for axis in range(3):
            try:
                # Estrategia de interpolación según la cantidad de datos
                if original_timesteps >= target_timesteps:
                    # Downsample: usar signal.resample para preservar características
                    resampled_axis = signal.resample(sensor_data[:, axis], target_timesteps)
                else:
                    # Upsample: usar interpolación
                    if len(np.unique(relative_times)) > 1:
                        interpolator = interp1d(
                            relative_times, 
                            sensor_data[:, axis],
                            kind='cubic' if original_timesteps >= 4 else 'linear',
                            bounds_error=False,
                            fill_value='extrapolate'
                        )
                        resampled_axis = interpolator(target_times)
                    else:
                        resampled_axis = np.full(target_timesteps, sensor_data[0, axis])
                
                resampled_data[:, axis] = resampled_axis
                
            except Exception as e:
                # Fallback: interpolación lineal simple
                resampled_data[:, axis] = np.interp(
                    target_times, relative_times, sensor_data[:, axis]
                )
        
        return resampled_data
    
    except Exception as e:
        print(f"Error en remuestreo robusto: {str(e)}")
        # Último fallback: replicar la primera muestra
        return np.tile(sensor_data[0], (target_timesteps, 1))


def is_window_quality_good(resampled_window, max_std_threshold=50.0):
    """
    Verifica la calidad final de una ventana remuestreada
    """
    # Verificar NaN o infinitos
    if np.any(np.isnan(resampled_window)) or np.any(np.isinf(resampled_window)):
        return False
    
    # Verificar valores extremos (posibles errores de interpolación)
    if np.any(np.abs(resampled_window) > 1000):  # Ajustar según tus datos
        return False
    
    # Verificar varianza (datos demasiado planos pueden indicar error)
    for axis in range(resampled_window.shape[1]):
        std_axis = np.std(resampled_window[:, axis])
        if std_axis > max_std_threshold:  # Varianza excesiva
            return False
        if std_axis < 0.001:  # Datos demasiado planos
            return False
    
    return True

# %%
# Análisis rápido de tiempos por usuario y actividad
# time_analysis = df_accel.to_pandas().groupby(['Subject-id', 'Activity Label'])['Timestamp'].agg(['min', 'max']).reset_index()
# time_analysis['duration_seconds'] = (pd.to_datetime(time_analysis['max']) - pd.to_datetime(time_analysis['min'])).dt.total_seconds()
# time_analysis['duration_hours'] = time_analysis['duration_seconds'] / 3600

# # Mostrar casos extremos
# print("🔍 DURACIONES POR USUARIO Y ACTIVIDAD:")
# time_analysis.sort_values('duration_seconds', ascending=False)
# Out:
# 🔍 DURACIONES POR USUARIO Y ACTIVIDAD:

# %%
def loso_cross_validation_raw_windows_robust(df_accel, df_gyro=None, model_architecture_func=None,
                                           window_seconds=5, overlap_percent=50, 
                                           sampling_rate=20, target_timesteps=250,
                                           epochs=30, batch_size=32, verbose=1, 
                                           save_results=True, results_path="loso_raw_windows"):
    """LOSO con validación robusta de ventanas"""
    
    print("🚀 INICIANDO LOSO CROSS-VALIDATION - VENTANAS RAW ROBUSTAS")
    print("=" * 70)
    
    # Usar la función robusta para crear ventanas
    X_all, y_all, subjects_all, metadata_all = create_raw_windows_250_timesteps_robust(
        df=df_accel,
        window_seconds=window_seconds,
        overlap_percent=overlap_percent,
        sampling_rate=sampling_rate,
        target_timesteps=target_timesteps,
        min_data_threshold=0.8,  # 80% mínimo de datos
        max_gap_seconds=1.0      # Máximo 1 segundo de gap
    )

    y_all_mapped = []
    for label in y_all:
        # Primero mapear con activities_
        mapped_activity = activities_[label]
        
        # Luego buscar en qué cluster está
        final_cluster = mapped_activity  # Por defecto, mantener la actividad
        for cluster_name, activities_in_cluster in cluster_.items():
            if mapped_activity in activities_in_cluster:
                final_cluster = cluster_name
                break
        
        y_all_mapped.append(final_cluster)
    
    y_all = np.array(y_all_mapped)
    print("Actividades únicas después del mapeo:", np.unique(y_all))
    
    if X_all is None:
        print("❌ No se pudieron crear ventanas válidas")
        return None
    
    # Obtener usuarios únicos
    users = np.unique(subjects_all)
    n_users = len(users)
    
    print(f"👥 Total de usuarios: {n_users}")
    print(f"📊 Usuarios: {users}")
    print(f"📊 Forma de datos: {X_all.shape}")
    
    # Preparar label encoder global
    from sklearn.preprocessing import LabelEncoder
    global_label_encoder = LabelEncoder()
    y_all_encoded = global_label_encoder.fit_transform(y_all)
    
    # Almacenar resultados
    loso_results = {
        'user': [],
        'accuracy': [],
        'precision_macro': [],
        'recall_macro': [],
        'f1_macro': [],
        'confusion_matrix': [],
        'classification_report': [],
        'train_windows': [],
        'test_windows': [],
        'y_true': [],
        'y_pred': []
    }
    
    all_y_true = []
    all_y_pred = []
    
    # Iterar sobre cada usuario (LOSO)
    for i, test_user in enumerate(users):
        print(f"\n🔄 FOLD {i+1}/{n_users}: Usuario de test = {test_user}")
        print("-" * 50)
        
        # División de datos: un usuario para test, resto para train
        train_mask = subjects_all != test_user
        test_mask = subjects_all == test_user
        
        X_train = X_all[train_mask]
        y_train = y_all_encoded[train_mask]
        X_test = X_all[test_mask]
        y_test = y_all_encoded[test_mask]
        
        print(f"📊 Train: {len(X_train)} ventanas de {len(np.unique(subjects_all[train_mask]))} usuarios")
        print(f"📊 Test: {len(X_test)} ventanas del usuario {test_user}")
        
        # Verificar que hay suficientes datos
        if len(X_train) < 50 or len(X_test) < 10:
            print(f"⚠️ Datos insuficientes para usuario {test_user}, saltando...")
            continue
        
        # Verificar clases en común
        train_classes = set(np.unique(y_train))
        test_classes = set(np.unique(y_test))
        common_classes = train_classes.intersection(test_classes)
        
        if len(common_classes) < 2:
            print(f"⚠️ Muy pocas clases comunes para usuario {test_user}, saltando...")
            continue
        
        print(f"🎯 Clases comunes: {len(common_classes)}")
        
        try:
            # Crear y compilar modelo
            input_shape = (target_timesteps, X_train.shape[2])
            num_classes = len(global_label_encoder.classes_)
            
            if model_architecture_func is None:
                model = create_cnn_lstm_model(input_shape=input_shape, num_classes=num_classes)
            else:
                model = model_architecture_func(input_shape=input_shape, num_classes=num_classes)
            
            # Entrenar modelo
            print(f"🏋️ Entrenando modelo...")
            history = model.fit(
                X_train, y_train,
                epochs=epochs,
                batch_size=batch_size,
                callbacks=callbacks,
                verbose=0 if verbose == 0 else 1,
                validation_split=0.1
            )
            
            # Evaluar modelo
            print(f"🔍 Evaluando modelo...")
            y_pred = model.predict(X_test, verbose=0)
            y_pred_classes = np.argmax(y_pred, axis=1)
            
            # Calcular métricas
            from sklearn.metrics import accuracy_score, precision_recall_fscore_support
            from sklearn.metrics import classification_report, confusion_matrix
            
            accuracy = accuracy_score(y_test, y_pred_classes)
            precision, recall, f1, _ = precision_recall_fscore_support(
                y_test, y_pred_classes, average='macro', zero_division=0
            )
            
            # Reporte de clasificación
            report = classification_report(
                y_test, y_pred_classes,
                target_names=global_label_encoder.classes_,
                output_dict=True,
                zero_division=0
            )
            
            # Matriz de confusión
            cm = confusion_matrix(y_test, y_pred_classes)
            
            # Guardar resultados
            loso_results['user'].append(test_user)
            loso_results['accuracy'].append(accuracy)
            loso_results['precision_macro'].append(precision)
            loso_results['recall_macro'].append(recall)
            loso_results['f1_macro'].append(f1)
            loso_results['confusion_matrix'].append(cm)
            loso_results['classification_report'].append(report)
            loso_results['train_windows'].append(len(X_train))
            loso_results['test_windows'].append(len(X_test))
            loso_results['y_true'].append(y_test)
            loso_results['y_pred'].append(y_pred_classes)
            
            # Acumular para métricas globales
            all_y_true.extend(y_test)
            all_y_pred.extend(y_pred_classes)
            
            print(f"✅ Usuario {test_user}: Accuracy = {accuracy:.4f}")
            
        except Exception as e:
            print(f"❌ Error con usuario {test_user}: {str(e)}")
            continue
    
    # Calcular métricas agregadas
    print(f"\n📊 RESULTADOS LOSO RAW WINDOWS")
    print("=" * 70)
    
    if len(loso_results['accuracy']) > 0:
        mean_accuracy = np.mean(loso_results['accuracy'])
        std_accuracy = np.std(loso_results['accuracy'])
        mean_precision = np.mean(loso_results['precision_macro'])
        mean_recall = np.mean(loso_results['recall_macro'])
        mean_f1 = np.mean(loso_results['f1_macro'])
        
        print(f"🎯 Accuracy promedio: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
        print(f"🎯 Precision promedio: {mean_precision:.4f}")
        print(f"🎯 Recall promedio: {mean_recall:.4f}")
        print(f"🎯 F1-Score promedio: {mean_f1:.4f}")
        print(f"📊 Usuarios evaluados: {len(loso_results['accuracy'])}/{n_users}")
        
        # Guardar resultados
        if save_results:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            
            results_df = pd.DataFrame({
                'user': loso_results['user'],
                'accuracy': loso_results['accuracy'],
                'precision_macro': loso_results['precision_macro'],
                'recall_macro': loso_results['recall_macro'],
                'f1_macro': loso_results['f1_macro'],
                'train_windows': loso_results['train_windows'],
                'test_windows': loso_results['test_windows']
            })
            
            results_df.to_csv(f"{results_path}_summary_{timestamp}.csv", index=False)
            joblib.dump(loso_results, f"{results_path}_complete_{timestamp}.joblib")
            
            print(f"💾 Resultados guardados: {results_path}_*_{timestamp}.*")
        
        return {
            'summary': results_df,
            'model': model,
            'mean_accuracy': mean_accuracy,
            'std_accuracy': std_accuracy,
            'mean_precision': mean_precision,
            'mean_recall': mean_recall,
            'mean_f1': mean_f1,
            'detailed_results': loso_results,
            'global_label_encoder': global_label_encoder
        }
    
    else:
        print("❌ No se pudieron evaluar usuarios")
        return None

# %%
# Cargar datos
path_base = r"F:\UPC\Tesis\HARbit-Model\src\data\wisdm-dataset\raw\watch"
sensor_data = load_sensors_separately(path_base)
df_gyro = sensor_data['gyro']
# df_gyro = df_gyro.rename({'X': 'X_gyro', 'Y': 'Y_gyro', 'Z': 'Z_gyro'})

df_accel = sensor_data['accel']
# df_accel = df_accel.rename({'X': 'X_accel', 'Y': 'Y_accel', 'Z': 'Z_accel'})

print(f"Giroscopio: {len(df_gyro)} muestras")
print(f"Acelerómetro: {len(df_accel)} muestras")
# Out:
# 2025-09-23 22:24:11.834 | INFO     | utils.data_loading:load_sensors_separately:64 - Cargando datos de gyro...
# 2025-09-23 22:24:23.267 | INFO     | utils.data_loading:load_sensors_separately:64 - Cargando datos de accel...
# Giroscopio: 3440341 muestras
# Acelerómetro: 3777045 muestras

# %%
# df_gyro = df_gyro.to_pandas()
# df_accel = df_accel.to_pandas()

# df_gyro['Activity Label']   = df_gyro['Activity Label'].apply(lambda x: activities_[x])
# df_accel['Activity Label']  = df_accel['Activity Label'].apply(lambda x: activities_[x])

# for activity in cluster_.keys():
#     for act in cluster_[activity]:
#         df_gyro.loc[df_gyro['Activity Label'] == act, 'Activity Label'] = activity
#         df_accel.loc[df_accel['Activity Label'] == act, 'Activity Label'] = activity

# %%
def compare_data_before_after_processing(df_original, X_processed, y_processed, subjects_processed, 
                                        metadata_df, window_seconds=5, target_timesteps=250):
    """
    Compara los datos originales con los procesados para validar el tratamiento
    
    Args:
        df_original: DataFrame original con datos de sensores
        X_processed: Array procesado con ventanas (n_windows, 250, 3)
        y_processed: Array con etiquetas procesadas
        subjects_processed: Array con IDs de usuario procesados
        metadata_df: DataFrame con metadata de las ventanas
        window_seconds: Duración de ventana en segundos
        target_timesteps: Timesteps objetivo por ventana
        
    Returns:
        dict: Reporte completo de comparación
    """
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    print("🔍 COMPARACIÓN DATOS ORIGINALES vs PROCESADOS")
    print("=" * 60)
    
    # ==================== ANÁLISIS GENERAL ====================
    print("\n📊 ESTADÍSTICAS GENERALES:")
    print("-" * 40)
    
    # Datos originales
    original_samples = len(df_original)
    original_users = df_original['Subject-id'].nunique()
    original_activities = df_original['Activity Label'].nunique()
    original_duration = (pd.to_datetime(df_original['Timestamp']).max() - 
                        pd.to_datetime(df_original['Timestamp']).min()).total_seconds()
    
    # Datos procesados
    processed_windows = len(X_processed) if X_processed is not None else 0
    processed_users = len(np.unique(subjects_processed)) if subjects_processed is not None else 0
    processed_activities = len(np.unique(y_processed)) if y_processed is not None else 0
    processed_duration = processed_windows * window_seconds if processed_windows > 0 else 0
    
    print(f"📈 ORIGINALES:")
    print(f"  Muestras totales: {original_samples:,}")
    print(f"  Usuarios únicos: {original_users}")
    print(f"  Actividades únicas: {original_activities}")
    print(f"  Duración total: {original_duration/3600:.1f} horas")
    
    print(f"\n📊 PROCESADOS:")
    print(f"  Ventanas creadas: {processed_windows:,}")
    print(f"  Usuarios conservados: {processed_users}")
    print(f"  Actividades conservadas: {processed_activities}")
    print(f"  Duración equivalente: {processed_duration/3600:.1f} horas")
    
    # Eficiencia de conversión
    if original_samples > 0:
        conversion_rate = (processed_windows * target_timesteps) / original_samples * 100
        print(f"\n🎯 EFICIENCIA DE CONVERSIÓN:")
        print(f"  Tasa de aprovechamiento: {conversion_rate:.1f}%")
        print(f"  Reducción de datos: {(1 - conversion_rate/100)*100:.1f}%")
    
    # ==================== ANÁLISIS POR USUARIO ====================
    print(f"\n👥 ANÁLISIS POR USUARIO:")
    print("-" * 40)
    
    user_comparison = []
    
    if X_processed is not None:
        for user_id in np.unique(subjects_processed):
            # Datos originales del usuario
            original_user_data = df_original[df_original['Subject-id'] == user_id]
            original_user_samples = len(original_user_data)
            original_user_activities = original_user_data['Activity Label'].nunique()
            
            # Datos procesados del usuario
            processed_user_windows = np.sum(subjects_processed == user_id)
            processed_user_activities = len(np.unique(y_processed[subjects_processed == user_id]))
            
            user_comparison.append({
                'user_id': user_id,
                'original_samples': original_user_samples,
                'original_activities': original_user_activities,
                'processed_windows': processed_user_windows,
                'processed_activities': processed_user_activities,
                'conversion_rate': (processed_user_windows * target_timesteps) / original_user_samples * 100 if original_user_samples > 0 else 0
            })
            
            print(f"Usuario {user_id}: {original_user_samples} → {processed_user_windows} ventanas ({processed_user_windows * target_timesteps} puntos)")
    
    # ==================== ANÁLISIS POR ACTIVIDAD ====================
    print(f"\n🏃 ANÁLISIS POR ACTIVIDAD:")
    print("-" * 40)
    
    activity_comparison = []
    
    if X_processed is not None:
        for activity in np.unique(y_processed):
            # Datos originales de la actividad
            original_activity_data = df_original[df_original['Activity Label'] == activity]
            original_activity_samples = len(original_activity_data)
            original_activity_users = original_activity_data['Subject-id'].nunique()
            
            # Datos procesados de la actividad
            processed_activity_windows = np.sum(y_processed == activity)
            processed_activity_users = len(np.unique(subjects_processed[y_processed == activity]))
            
            activity_comparison.append({
                'activity': activity,
                'original_samples': original_activity_samples,
                'original_users': original_activity_users,
                'processed_windows': processed_activity_windows,
                'processed_users': processed_activity_users,
                'conversion_rate': (processed_activity_windows * target_timesteps) / original_activity_samples * 100 if original_activity_samples > 0 else 0
            })
            
            print(f"{activity}: {original_activity_samples} → {processed_activity_windows} ventanas")
    
    # ==================== ANÁLISIS DE CALIDAD DE DATOS ====================
    print(f"\n🔬 ANÁLISIS DE CALIDAD:")
    print("-" * 40)
    
    if X_processed is not None:
        # Estadísticas de los datos procesados
        print(f"📊 Estadísticas de ventanas procesadas:")
        print(f"  Forma de X: {X_processed.shape}")
        print(f"  Rango de valores:")
        print(f"    Min: {X_processed.min():.3f}")
        print(f"    Max: {X_processed.max():.3f}")
        print(f"    Media: {X_processed.mean():.3f}")
        print(f"    Std: {X_processed.std():.3f}")
        
        # Verificar datos anómalos
        nan_count = np.isnan(X_processed).sum()
        inf_count = np.isinf(X_processed).sum()
        extreme_count = np.sum(np.abs(X_processed) > 1000)
        
        print(f"\n🚨 Verificación de anomalías:")
        print(f"  Valores NaN: {nan_count}")
        print(f"  Valores infinitos: {inf_count}")
        print(f"  Valores extremos (>1000): {extreme_count}")
        
        if nan_count == 0 and inf_count == 0 and extreme_count == 0:
            print("  ✅ Sin anomalías detectadas")
        else:
            print("  ❌ Se encontraron anomalías")
    
    # ==================== ANÁLISIS TEMPORAL ====================
    if metadata_df is not None and len(metadata_df) > 0:
        print(f"\n⏰ ANÁLISIS TEMPORAL:")
        print("-" * 40)
        
        # Cobertura de datos por ventana
        coverage_stats = metadata_df['data_coverage'].describe()
        print(f"📊 Cobertura de datos por ventana:")
        print(f"  Promedio: {coverage_stats['mean']:.3f}")
        print(f"  Mínimo: {coverage_stats['min']:.3f}")
        print(f"  Máximo: {coverage_stats['max']:.3f}")
        
        # Gaps por ventana
        gap_stats = metadata_df['max_gap_s'].describe()
        print(f"\n🕳️ Gaps por ventana:")
        print(f"  Gap promedio: {gap_stats['mean']:.3f}s")
        print(f"  Gap máximo: {gap_stats['max']:.3f}s")
        
        # Frecuencia de muestreo real
        rate_stats = metadata_df['sampling_rate_actual'].describe()
        print(f"\n📡 Frecuencia de muestreo real:")
        print(f"  Promedio: {rate_stats['mean']:.1f}Hz")
        print(f"  Rango: {rate_stats['min']:.1f} - {rate_stats['max']:.1f}Hz")
    
    # ==================== VISUALIZACIONES ====================
    if X_processed is not None:
        create_comparison_visualizations(
            df_original, X_processed, y_processed, subjects_processed, 
            user_comparison, activity_comparison, metadata_df
        )
    
    # ==================== REPORTE FINAL ====================
    report = {
        'original_stats': {
            'samples': original_samples,
            'users': original_users,
            'activities': original_activities,
            'duration_hours': original_duration/3600
        },
        'processed_stats': {
            'windows': processed_windows,
            'users': processed_users,
            'activities': processed_activities,
            'duration_hours': processed_duration/3600
        },
        'conversion_rate': conversion_rate if 'conversion_rate' in locals() else 0,
        'user_comparison': user_comparison,
        'activity_comparison': activity_comparison,
        'quality_check': {
            'nan_count': nan_count if 'nan_count' in locals() else 0,
            'inf_count': inf_count if 'inf_count' in locals() else 0,
            'extreme_count': extreme_count if 'extreme_count' in locals() else 0
        }
    }
    
    return report


def create_comparison_visualizations(df_original, X_processed, y_processed, subjects_processed, 
                                   user_comparison, activity_comparison, metadata_df):
    """
    Crea visualizaciones para comparar datos originales vs procesados
    """
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    fig.suptitle('Comparación: Datos Originales vs Procesados', fontsize=16, fontweight='bold')
    
    # 1. Distribución por usuarios
    if user_comparison:
        user_df = pd.DataFrame(user_comparison)
        
        axes[0,0].bar(range(len(user_df)), user_df['original_samples'], alpha=0.7, label='Original', color='lightblue')
        axes[0,0].bar(range(len(user_df)), user_df['processed_windows'] * 250, alpha=0.7, label='Procesado', color='orange')
        axes[0,0].set_title('Muestras por Usuario')
        axes[0,0].set_xlabel('Usuario')
        axes[0,0].set_ylabel('Número de Muestras')
        axes[0,0].legend()
        axes[0,0].set_xticks(range(len(user_df)))
        axes[0,0].set_xticklabels([f"U{int(u)}" for u in user_df['user_id']], rotation=45)
    
    # 2. Distribución por actividades
    if activity_comparison:
        activity_df = pd.DataFrame(activity_comparison)
        
        x_pos = range(len(activity_df))
        width = 0.35
        
        axes[0,1].bar([x - width/2 for x in x_pos], activity_df['original_samples'], 
                      width, label='Original', alpha=0.7, color='lightblue')
        axes[0,1].bar([x + width/2 for x in x_pos], activity_df['processed_windows'] * 250, 
                      width, label='Procesado', alpha=0.7, color='orange')
        axes[0,1].set_title('Muestras por Actividad')
        axes[0,1].set_xlabel('Actividad')
        axes[0,1].set_ylabel('Número de Muestras')
        axes[0,1].legend()
        axes[0,1].set_xticks(x_pos)
        axes[0,1].set_xticklabels(activity_df['activity'], rotation=45)
    
    # 3. Tasas de conversión por usuario
    if user_comparison:
        axes[0,2].bar(range(len(user_df)), user_df['conversion_rate'], alpha=0.7, color='green')
        axes[0,2].set_title('Tasa de Conversión por Usuario')
        axes[0,2].set_xlabel('Usuario')
        axes[0,2].set_ylabel('Tasa de Conversión (%)')
        axes[0,2].set_xticks(range(len(user_df)))
        axes[0,2].set_xticklabels([f"U{int(u)}" for u in user_df['user_id']], rotation=45)
    
    # 4. Distribución de valores originales vs procesados
    original_sample = df_original[['X', 'Y', 'Z']].sample(10000) if len(df_original) > 10000 else df_original[['X', 'Y', 'Z']]
    processed_sample = X_processed.reshape(-1, X_processed.shape[-1])
    processed_sample = processed_sample[::max(1, len(processed_sample)//10000)]  # Muestra de 10k
    
    axes[1,0].hist(original_sample.values.flatten(), bins=50, alpha=0.5, label='Original', density=True)
    axes[1,0].hist(processed_sample.flatten(), bins=50, alpha=0.5, label='Procesado', density=True)
    axes[1,0].set_title('Distribución de Valores de Sensores')
    axes[1,0].set_xlabel('Valor del Sensor')
    axes[1,0].set_ylabel('Densidad')
    axes[1,0].legend()
    
    # 5. Cobertura de datos (si hay metadata)
    if metadata_df is not None and len(metadata_df) > 0:
        axes[1,1].hist(metadata_df['data_coverage'], bins=30, alpha=0.7, color='purple')
        axes[1,1].set_title('Distribución de Cobertura de Datos')
        axes[1,1].set_xlabel('Cobertura de Datos')
        axes[1,1].set_ylabel('Frecuencia')
        axes[1,1].axvline(metadata_df['data_coverage'].mean(), color='red', linestyle='--', 
                         label=f'Media: {metadata_df["data_coverage"].mean():.3f}')
        axes[1,1].legend()
    
    # 6. Ejemplo de ventana procesada
    if X_processed is not None and len(X_processed) > 0:
        sample_window = X_processed[0]  # Primera ventana como ejemplo
        axes[1,2].plot(sample_window[:, 0], label='X', alpha=0.7)
        axes[1,2].plot(sample_window[:, 1], label='Y', alpha=0.7)
        axes[1,2].plot(sample_window[:, 2], label='Z', alpha=0.7)
        axes[1,2].set_title('Ejemplo de Ventana Procesada (250 timesteps)')
        axes[1,2].set_xlabel('Timestep')
        axes[1,2].set_ylabel('Valor del Sensor')
        axes[1,2].legend()
        axes[1,2].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()


def validate_processing_integrity(df_original, X_processed, y_processed, subjects_processed, 
                                window_seconds=5, target_timesteps=250, sampling_rate=20):
    """
    Valida la integridad del procesamiento de datos
    
    Returns:
        dict: Resultado de validación con checks específicos
    """
    print("🔍 VALIDACIÓN DE INTEGRIDAD DEL PROCESAMIENTO")
    print("=" * 50)
    
    validation_results = {
        'shape_check': False,
        'data_range_check': False,
        'temporal_consistency_check': False,
        'user_preservation_check': False,
        'activity_preservation_check': False,
        'overall_valid': False,
        'issues': []
    }
    
    if X_processed is None:
        validation_results['issues'].append("X_processed es None")
        return validation_results
    
    # 1. Verificar forma de datos
    expected_shape = (None, target_timesteps, 3)  # (n_windows, 250, 3)
    actual_shape = X_processed.shape
    
    if len(actual_shape) == 3 and actual_shape[1] == target_timesteps and actual_shape[2] == 3:
        validation_results['shape_check'] = True
        print("✅ Forma de datos correcta:", actual_shape)
    else:
        validation_results['issues'].append(f"Forma incorrecta: {actual_shape}, esperada: (n_windows, {target_timesteps}, 3)")
        print("❌ Forma de datos incorrecta:", actual_shape)
    
    # 2. Verificar rango de datos
    if not np.any(np.isnan(X_processed)) and not np.any(np.isinf(X_processed)):
        data_range = X_processed.max() - X_processed.min()
        if data_range > 0 and X_processed.max() < 1000 and X_processed.min() > -1000:
            validation_results['data_range_check'] = True
            print("✅ Rango de datos válido:", f"{X_processed.min():.3f} a {X_processed.max():.3f}")
        else:
            validation_results['issues'].append(f"Rango de datos sospechoso: {X_processed.min():.3f} a {X_processed.max():.3f}")
            print("❌ Rango de datos sospechoso")
    else:
        validation_results['issues'].append("Datos contienen NaN o infinitos")
        print("❌ Datos contienen NaN o infinitos")
    
    # 3. Verificar consistencia temporal
    expected_total_duration = len(X_processed) * window_seconds
    original_duration = (pd.to_datetime(df_original['Timestamp']).max() - 
                        pd.to_datetime(df_original['Timestamp']).min()).total_seconds()
    
    duration_ratio = expected_total_duration / original_duration
    if 0.1 <= duration_ratio <= 1.5:  # Permitir cierta flexibilidad
        validation_results['temporal_consistency_check'] = True
        print("✅ Consistencia temporal válida:", f"{duration_ratio:.2f} ratio")
    else:
        validation_results['issues'].append(f"Inconsistencia temporal: ratio {duration_ratio:.2f}")
        print("❌ Inconsistencia temporal:", f"ratio {duration_ratio:.2f}")
    
    # 4. Verificar preservación de usuarios
    original_users = set(df_original['Subject-id'].unique())
    processed_users = set(subjects_processed) if subjects_processed is not None else set()
    
    if processed_users.issubset(original_users) and len(processed_users) >= len(original_users) * 0.5:
        validation_results['user_preservation_check'] = True
        print("✅ Preservación de usuarios válida:", f"{len(processed_users)}/{len(original_users)}")
    else:
        validation_results['issues'].append(f"Pérdida excesiva de usuarios: {len(processed_users)}/{len(original_users)}")
        print("❌ Pérdida excesiva de usuarios")
    
    # 5. Verificar preservación de actividades
    original_activities = set(df_original['Activity Label'].unique())
    processed_activities = set(y_processed) if y_processed is not None else set()
    
    if processed_activities.issubset(original_activities) and len(processed_activities) >= len(original_activities) * 0.8:
        validation_results['activity_preservation_check'] = True
        print("✅ Preservación de actividades válida:", f"{len(processed_activities)}/{len(original_activities)}")
    else:
        validation_results['issues'].append(f"Pérdida de actividades: {len(processed_activities)}/{len(original_activities)}")
        print("❌ Pérdida de actividades")
    
    # Verificación general
    all_checks = [
        validation_results['shape_check'],
        validation_results['data_range_check'],
        validation_results['temporal_consistency_check'],
        validation_results['user_preservation_check'],
        validation_results['activity_preservation_check']
    ]
    
    validation_results['overall_valid'] = all(all_checks)
    
    print(f"\n🎯 RESULTADO GENERAL: {'✅ VÁLIDO' if validation_results['overall_valid'] else '❌ INVÁLIDO'}")
    
    if validation_results['issues']:
        print("\n🚨 PROBLEMAS DETECTADOS:")
        for issue in validation_results['issues']:
            print(f"  - {issue}")
    
    return validation_results

# %%
# # Después de procesar tus datos con la función robusta
# X_all, y_all, subjects_all, metadata_all = create_raw_windows_250_timesteps_robust(
#     df=df_accel,
#     window_seconds=5,
#     overlap_percent=50,
#     sampling_rate=20,
#     target_timesteps=250,
#     min_data_threshold=0.6,
#     max_gap_seconds=1.0
# )

# # Realizar comparación completa
# print("🔍 COMPARANDO DATOS ORIGINALES vs PROCESADOS...")
# comparison_report = compare_data_before_after_processing(
#     df_original=df_accel,
#     X_processed=X_all,
#     y_processed=y_all,
#     subjects_processed=subjects_all,
#     metadata_df=metadata_all,
#     window_seconds=5,
#     target_timesteps=250
# )

# # Validar integridad del procesamiento
# print("\n🔍 VALIDANDO INTEGRIDAD...")
# validation_report = validate_processing_integrity(
#     df_original=df_accel,
#     X_processed=X_all,
#     y_processed=y_all,
#     subjects_processed=subjects_all,
#     window_seconds=5,
#     target_timesteps=250,
#     sampling_rate=20
# )

# # Mostrar resumen
# if validation_report['overall_valid']:
#     print("\n🎉 ¡PROCESAMIENTO EXITOSO!")
#     print("Los datos han sido procesados correctamente y están listos para entrenamiento.")
# else:
#     print("\n⚠️ PROCESAMIENTO CO# Después de procesar tus datos con la función robusta")
# X_all, y_all, subjects_all, metadata_all = create_raw_windows_250_timesteps_robust(
#     df=df_accel,
#     window_seconds=5,
#     overlap_percent=50,
#     sampling_rate=20,
#     target_timesteps=250,
#     min_data_threshold=0.6,
#     max_gap_seconds=1.0
# )

# # Realizar comparación completa
# print("🔍 COMPARANDO DATOS ORIGINALES vs PROCESADOS...")
# comparison_report = compare_data_before_after_processing(
#     df_original=df_accel,
#     X_processed=X_all,
#     y_processed=y_all,
#     subjects_processed=subjects_all,
#     metadata_df=metadata_all,
#     window_seconds=5,
#     target_timesteps=250
# )

# # Validar integridad del procesamiento
# print("\n🔍 VALIDANDO INTEGRIDAD...")
# validation_report = validate_processing_integrity(
#     df_original=df_accel,
#     X_processed=X_all,
#     y_processed=y_all,
#     subjects_processed=subjects_all,
#     window_seconds=5,
#     target_timesteps=250,
#     sampling_rate=20
# )

# %%
# Luego ejecuta el LOSO corregido
print("\n🚀 Ejecutando LOSO con ventanas RAW CORREGIDAS...")

# Ejecutar LOSO con la función corregida
loso_results = loso_cross_validation_raw_windows_robust(
    df_accel=df_accel,
    df_gyro=None,
    model_architecture_func=create_cnn_lstm_model,
    window_seconds=5,
    overlap_percent=50,
    sampling_rate=20,
    target_timesteps=250,
    epochs=20,
    batch_size=32,
    verbose=1,
    save_results=True,
    results_path="loso_raw_robust"
)

# Mostrar resultados
if loso_results:
    print(f"✅ LOSO RAW completado!")
    print(f"📊 Accuracy promedio: {loso_results['mean_accuracy']:.4f}")
    print(f"📊 Std Accuracy: {loso_results['std_accuracy']:.4f}")
else:
    print("❌ LOSO falló - revisa los datos")
# Out:
# 🚀 Ejecutando LOSO con ventanas RAW CORREGIDAS...
# 🚀 INICIANDO LOSO CROSS-VALIDATION - VENTANAS RAW ROBUSTAS
# ======================================================================
# 🔧 Configuración de ventanas RAW ROBUSTA:
#   Duración: 5s
#   Timesteps objetivo: 250
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Umbral mínimo de datos: 80.0%
#   Máximo gap permitido: 1.0s
#   Duración de ventana: 5s
#   Paso entre ventanas: 2.50s
# 👤 Usuario 1600.0, Actividad A: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad C: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad D: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad G: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad I: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad K: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad M: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad O: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad Q: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1600.0, Actividad S: 4176 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad A: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad B: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad C: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad D: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad E: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad F: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad G: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad H: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad I: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad J: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad K: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad L: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad M: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad O: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad P: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad Q: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad R: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1601.0, Actividad S: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad B: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad E: 3701 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad G: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad H: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad R: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1602.0, Actividad S: 3608 muestras
#    Duración total: 180.2s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1603.0, Actividad A: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad B: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad C: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad D: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad E: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad F: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad G: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad H: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad I: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad J: 3620 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad K: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad L: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad M: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad O: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad P: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad Q: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad R: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1603.0, Actividad S: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad C: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad D: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad F: 3618 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1604.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad A: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad B: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad C: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad D: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad E: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad F: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad G: 3615 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad H: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad I: 4936 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad J: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad K: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad L: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad M: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad O: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad P: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad Q: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad R: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1605.0, Actividad S: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad A: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad B: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad D: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad O: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad P: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad R: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1606.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad A: 3604 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1607.0, Actividad B: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad C: 3608 muestras
#    Duración total: 180.4s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1607.0, Actividad D: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad E: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad F: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad G: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad H: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad I: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad J: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad K: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad L: 4578 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad M: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad O: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad P: 3604 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1607.0, Actividad Q: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad R: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1607.0, Actividad S: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad C: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad D: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad G: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad H: 3611 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad J: 6907 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad L: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1608.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad K: 6072 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad M: 4049 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad O: 4873 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad P: 4193 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1609.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad C: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad D: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad E: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad G: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad M: 3621 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad Q: 3614 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1610.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad B: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad D: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad O: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1611.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad A: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad B: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad C: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad J: 3620 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad K: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad L: 3986 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1612.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad A: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad B: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad C: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad D: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad E: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad F: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad G: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad H: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad I: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad J: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad K: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad L: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad M: 3603 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad O: 3611 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad P: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad Q: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad R: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1613.0, Actividad S: 3620 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad A: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad B: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad C: 3618 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad D: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad E: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad F: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad G: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad H: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad I: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad J: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad K: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad L: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad M: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad O: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad P: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad Q: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad R: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1614.0, Actividad S: 3603 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad Q: 3620 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1615.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad P: 5712 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad R: 3620 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad A: 3604 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad F: 3619 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad A: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad B: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad C: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad D: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad E: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad F: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad G: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad H: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad I: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad J: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad K: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad L: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad M: 3602 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad O: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad P: 3618 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad Q: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad R: 3618 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad S: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad Q: 5909 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad A: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad B: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad C: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad D: 7920 muestras
#    Duración total: 180.1s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1621.0, Actividad E: 5818 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad F: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad G: 3604 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad H: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad I: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad J: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad K: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad L: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad M: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad O: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad P: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad Q: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad R: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad S: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad A: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad C: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad D: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad P: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad A: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad B: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad D: 3590 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad M: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad O: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad P: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad Q: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad R: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad S: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad A: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad B: 3614 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad C: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad D: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad E: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad F: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad I: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad M: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad O: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad P: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad Q: 7935 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad R: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1624.0, Actividad S: 5644 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad A: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad B: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad C: 3618 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad D: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad E: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad F: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad G: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad H: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad I: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad J: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad K: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad L: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad M: 3606 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1625.0, Actividad O: 5404 muestras
#    Duración total: 179.9s
# ...
# Restoring model weights from the end of the best epoch: 17.
# 🔍 Evaluando modelo...
# ✅ Usuario 1600.0: Accuracy = 0.9889
#
# 🔄 FOLD 2/51: Usuario de test = 1601.0
# --------------------------------------------------
# 📊 Train: 62605 ventanas de 50 usuarios
# 📊 Test: 1260 ventanas del usuario 1601.0
# 🎯 Clases comunes: 8
# 🏋️ Entrenando modelo...
# Epoch 1/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 658s 368ms/step - accuracy: 0.5988 - loss: 1.0882 - val_accuracy: 0.6913 - val_loss: 0.8196 - learning_rate: 0.0010
# Epoch 2/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 651s 369ms/step - accuracy: 0.7222 - loss: 0.7895 - val_accuracy: 0.7601 - val_loss: 0.6719 - learning_rate: 0.0010
# Epoch 3/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 642s 364ms/step - accuracy: 0.7605 - loss: 0.6949 - val_accuracy: 0.7938 - val_loss: 0.6164 - learning_rate: 0.0010
# Epoch 4/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 640s 364ms/step - accuracy: 0.7851 - loss: 0.6321 - val_accuracy: 0.8016 - val_loss: 0.5690 - learning_rate: 0.0010
# Epoch 5/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 642s 364ms/step - accuracy: 0.8019 - loss: 0.5835 - val_accuracy: 0.8010 - val_loss: 0.5439 - learning_rate: 0.0010
# Epoch 6/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 638s 362ms/step - accuracy: 0.8147 - loss: 0.5454 - val_accuracy: 0.8238 - val_loss: 0.4881 - learning_rate: 0.0010
# Epoch 7/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 636s 361ms/step - accuracy: 0.8241 - loss: 0.5211 - val_accuracy: 0.8198 - val_loss: 0.5395 - learning_rate: 0.0010
# Epoch 8/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8302 - loss: 0.5046
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 637s 362ms/step - accuracy: 0.8313 - loss: 0.5033 - val_accuracy: 0.8194 - val_loss: 0.5078 - learning_rate: 0.0010
# Epoch 9/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 636s 361ms/step - accuracy: 0.8486 - loss: 0.4432 - val_accuracy: 0.8374 - val_loss: 0.4582 - learning_rate: 5.0000e-04
# Epoch 10/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 631s 359ms/step - accuracy: 0.8556 - loss: 0.4223 - val_accuracy: 0.8428 - val_loss: 0.4460 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 634s 360ms/step - accuracy: 0.8618 - loss: 0.4049 - val_accuracy: 0.8411 - val_loss: 0.4683 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 636s 361ms/step - accuracy: 0.8662 - loss: 0.3942 - val_accuracy: 0.8503 - val_loss: 0.4423 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 631s 358ms/step - accuracy: 0.8680 - loss: 0.3877 - val_accuracy: 0.8414 - val_loss: 0.4572 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 680s 386ms/step - accuracy: 0.8706 - loss: 0.3768 - val_accuracy: 0.8355 - val_loss: 0.4724 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 635s 360ms/step - accuracy: 0.8723 - loss: 0.3699 - val_accuracy: 0.8483 - val_loss: 0.4412 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8734 - loss: 0.3720
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 635s 361ms/step - accuracy: 0.8740 - loss: 0.3697 - val_accuracy: 0.8505 - val_loss: 0.4433 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 632s 359ms/step - accuracy: 0.8835 - loss: 0.3414 - val_accuracy: 0.8430 - val_loss: 0.4621 - learning_rate: 2.5000e-04
# Epoch 18/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 635s 360ms/step - accuracy: 0.8851 - loss: 0.3320 - val_accuracy: 0.8526 - val_loss: 0.4496 - learning_rate: 2.5000e-04
# Epoch 19/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 635s 360ms/step - accuracy: 0.8864 - loss: 0.3289 - val_accuracy: 0.8539 - val_loss: 0.4573 - learning_rate: 2.5000e-04
# Epoch 20/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 634s 360ms/step - accuracy: 0.8885 - loss: 0.3242 - val_accuracy: 0.8567 - val_loss: 0.4338 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 1.
# 🔍 Evaluando modelo...
# ✅ Usuario 1601.0: Accuracy = 0.3770
#
# 🔄 FOLD 3/51: Usuario de test = 1602.0
# --------------------------------------------------
# 📊 Train: 62604 ventanas de 50 usuarios
# 📊 Test: 1261 ventanas del usuario 1602.0
# 🎯 Clases comunes: 8
# 🏋️ Entrenando modelo...
# Epoch 1/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 684s 385ms/step - accuracy: 0.5909 - loss: 1.1082 - val_accuracy: 0.7168 - val_loss: 0.7523 - learning_rate: 0.0010
# Epoch 2/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 674s 383ms/step - accuracy: 0.7108 - loss: 0.8198 - val_accuracy: 0.7298 - val_loss: 0.7427 - learning_rate: 0.0010
# Epoch 3/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 673s 382ms/step - accuracy: 0.7432 - loss: 0.7397 - val_accuracy: 0.7962 - val_loss: 0.5782 - learning_rate: 0.0010
# Epoch 4/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 676s 384ms/step - accuracy: 0.7758 - loss: 0.6560 - val_accuracy: 0.8363 - val_loss: 0.5012 - learning_rate: 0.0010
# Epoch 5/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 676s 384ms/step - accuracy: 0.7891 - loss: 0.6144 - val_accuracy: 0.8074 - val_loss: 0.5316 - learning_rate: 0.0010
# Epoch 6/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 675s 383ms/step - accuracy: 0.8095 - loss: 0.5602 - val_accuracy: 0.7895 - val_loss: 0.5839 - learning_rate: 0.0010
# Epoch 7/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 676s 384ms/step - accuracy: 0.8153 - loss: 0.5401 - val_accuracy: 0.8379 - val_loss: 0.4879 - learning_rate: 0.0010
# Epoch 8/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8218 - loss: 0.5227
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 675s 383ms/step - accuracy: 0.8218 - loss: 0.5225 - val_accuracy: 0.8558 - val_loss: 0.4561 - learning_rate: 0.0010
# Epoch 9/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 674s 383ms/step - accuracy: 0.8388 - loss: 0.4667 - val_accuracy: 0.8615 - val_loss: 0.4300 - learning_rate: 5.0000e-04
# Epoch 10/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 677s 384ms/step - accuracy: 0.8493 - loss: 0.4367 - val_accuracy: 0.8254 - val_loss: 0.5050 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 674s 383ms/step - accuracy: 0.8507 - loss: 0.4318 - val_accuracy: 0.8588 - val_loss: 0.4254 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 672s 381ms/step - accuracy: 0.8572 - loss: 0.4173 - val_accuracy: 0.8547 - val_loss: 0.4317 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 674s 383ms/step - accuracy: 0.8576 - loss: 0.4127 - val_accuracy: 0.8781 - val_loss: 0.3839 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 667s 379ms/step - accuracy: 0.8595 - loss: 0.4056 - val_accuracy: 0.8425 - val_loss: 0.4425 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 665s 378ms/step - accuracy: 0.8651 - loss: 0.3917 - val_accuracy: 0.8526 - val_loss: 0.4476 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 664s 377ms/step - accuracy: 0.8642 - loss: 0.3922 - val_accuracy: 0.8559 - val_loss: 0.4410 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 662s 376ms/step - accuracy: 0.8661 - loss: 0.3857 - val_accuracy: 0.8543 - val_loss: 0.4180 - learning_rate: 5.0000e-04
# Epoch 18/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 676s 384ms/step - accuracy: 0.8691 - loss: 0.3791 - val_accuracy: 0.8532 - val_loss: 0.4594 - learning_rate: 5.0000e-04
# Epoch 19/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 655s 372ms/step - accuracy: 0.8707 - loss: 0.3740 - val_accuracy: 0.8468 - val_loss: 0.4429 - learning_rate: 5.0000e-04
# Epoch 20/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 636s 361ms/step - accuracy: 0.8735 - loss: 0.3659 - val_accuracy: 0.8626 - val_loss: 0.4128 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 13.
# 🔍 Evaluando modelo...
# ✅ Usuario 1602.0: Accuracy = 0.9389
#
# 🔄 FOLD 4/51: Usuario de test = 1603.0
# --------------------------------------------------
# 📊 Train: 62605 ventanas de 50 usuarios
# 📊 Test: 1260 ventanas del usuario 1603.0
# 🎯 Clases comunes: 8
# 🏋️ Entrenando modelo...
# Epoch 1/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 710s 400ms/step - accuracy: 0.5958 - loss: 1.0978 - val_accuracy: 0.6638 - val_loss: 0.8180 - learning_rate: 0.0010
# Epoch 2/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 700s 397ms/step - accuracy: 0.7050 - loss: 0.8249 - val_accuracy: 0.7580 - val_loss: 0.6385 - learning_rate: 0.0010
# Epoch 3/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 785s 446ms/step - accuracy: 0.7496 - loss: 0.7215 - val_accuracy: 0.7673 - val_loss: 0.6521 - learning_rate: 0.0010
# Epoch 4/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 755s 429ms/step - accuracy: 0.7811 - loss: 0.6397 - val_accuracy: 0.8034 - val_loss: 0.5972 - learning_rate: 0.0010
# Epoch 5/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 716s 406ms/step - accuracy: 0.7952 - loss: 0.6027 - val_accuracy: 0.8024 - val_loss: 0.5423 - learning_rate: 0.0010
# Epoch 6/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 716s 407ms/step - accuracy: 0.8100 - loss: 0.5587 - val_accuracy: 0.8360 - val_loss: 0.4786 - learning_rate: 0.0010
# Epoch 7/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 703s 399ms/step - accuracy: 0.8191 - loss: 0.5327 - val_accuracy: 0.8251 - val_loss: 0.5140 - learning_rate: 0.0010
# Epoch 8/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.8266 - loss: 0.5126
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 649s 369ms/step - accuracy: 0.8282 - loss: 0.5092 - val_accuracy: 0.8515 - val_loss: 0.4430 - learning_rate: 0.0010
# Epoch 9/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 713s 405ms/step - accuracy: 0.8483 - loss: 0.4491 - val_accuracy: 0.8395 - val_loss: 0.4479 - learning_rate: 5.0000e-04
# Epoch 10/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 713s 405ms/step - accuracy: 0.8531 - loss: 0.4313 - val_accuracy: 0.8456 - val_loss: 0.4303 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 716s 406ms/step - accuracy: 0.8559 - loss: 0.4184 - val_accuracy: 0.8591 - val_loss: 0.4267 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 709s 402ms/step - accuracy: 0.8630 - loss: 0.4033 - val_accuracy: 0.8382 - val_loss: 0.4731 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 706s 401ms/step - accuracy: 0.8648 - loss: 0.3957 - val_accuracy: 0.8559 - val_loss: 0.4404 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 738s 398ms/step - accuracy: 0.8653 - loss: 0.3905 - val_accuracy: 0.8497 - val_loss: 0.4199 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 708s 402ms/step - accuracy: 0.8677 - loss: 0.3821 - val_accuracy: 0.8604 - val_loss: 0.4129 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.8671 - loss: 0.3778
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 720s 409ms/step - accuracy: 0.8662 - loss: 0.3850 - val_accuracy: 0.8671 - val_loss: 0.3937 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 706s 401ms/step - accuracy: 0.8775 - loss: 0.3554 - val_accuracy: 0.8563 - val_loss: 0.4162 - learning_rate: 2.5000e-04
# Epoch 18/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 708s 402ms/step - accuracy: 0.8816 - loss: 0.3435 - val_accuracy: 0.8602 - val_loss: 0.4106 - learning_rate: 2.5000e-04
# Epoch 19/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 710s 403ms/step - accuracy: 0.8828 - loss: 0.3382 - val_accuracy: 0.8642 - val_loss: 0.3959 - learning_rate: 2.5000e-04
# Epoch 20/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 705s 400ms/step - accuracy: 0.8846 - loss: 0.3323 - val_accuracy: 0.8678 - val_loss: 0.3864 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 1.
# 🔍 Evaluando modelo...
# ✅ Usuario 1603.0: Accuracy = 0.8111
#
# 🔄 FOLD 5/51: Usuario de test = 1604.0
# --------------------------------------------------
# 📊 Train: 62605 ventanas de 50 usuarios
# 📊 Test: 1260 ventanas del usuario 1604.0
# 🎯 Clases comunes: 8
# 🏋️ Entrenando modelo...
# Epoch 1/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 767s 429ms/step - accuracy: 0.5868 - loss: 1.1133 - val_accuracy: 0.6580 - val_loss: 0.9363 - learning_rate: 0.0010
# Epoch 2/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 751s 427ms/step - accuracy: 0.7091 - loss: 0.8198 - val_accuracy: 0.7865 - val_loss: 0.6129 - learning_rate: 0.0010
# Epoch 3/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 751s 427ms/step - accuracy: 0.7488 - loss: 0.7165 - val_accuracy: 0.7582 - val_loss: 0.6268 - learning_rate: 0.0010
# Epoch 4/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 748s 425ms/step - accuracy: 0.7823 - loss: 0.6330 - val_accuracy: 0.7885 - val_loss: 0.6143 - learning_rate: 0.0010
# Epoch 5/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 751s 427ms/step - accuracy: 0.7930 - loss: 0.6012 - val_accuracy: 0.8329 - val_loss: 0.4835 - learning_rate: 0.0010
# Epoch 6/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 756s 429ms/step - accuracy: 0.8098 - loss: 0.5557 - val_accuracy: 0.8069 - val_loss: 0.5768 - learning_rate: 0.0010
# Epoch 7/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 751s 427ms/step - accuracy: 0.8147 - loss: 0.5392 - val_accuracy: 0.7994 - val_loss: 0.5552 - learning_rate: 0.0010
# Epoch 8/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8252 - loss: 0.5098
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 754s 428ms/step - accuracy: 0.8265 - loss: 0.5029 - val_accuracy: 0.8218 - val_loss: 0.4873 - learning_rate: 0.0010
# Epoch 9/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 752s 427ms/step - accuracy: 0.8458 - loss: 0.4492 - val_accuracy: 0.8404 - val_loss: 0.4393 - learning_rate: 5.0000e-04
# Epoch 10/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 4626s 3s/step - accuracy: 0.8527 - loss: 0.4314 - val_accuracy: 0.8663 - val_loss: 0.4049 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 749s 425ms/step - accuracy: 0.8567 - loss: 0.4130 - val_accuracy: 0.8566 - val_loss: 0.4331 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 791s 449ms/step - accuracy: 0.8606 - loss: 0.4022 - val_accuracy: 0.8598 - val_loss: 0.4062 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 1202s 683ms/step - accuracy: 0.8615 - loss: 0.3967 - val_accuracy: 0.8444 - val_loss: 0.4357 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 1314s 746ms/step - accuracy: 0.8649 - loss: 0.3917 - val_accuracy: 0.8524 - val_loss: 0.4282 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 909s 516ms/step - accuracy: 0.8665 - loss: 0.3848 - val_accuracy: 0.8606 - val_loss: 0.4008 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8688 - loss: 0.3775
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 868s 493ms/step - accuracy: 0.8691 - loss: 0.3763 - val_accuracy: 0.8518 - val_loss: 0.4263 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 826s 469ms/step - accuracy: 0.8777 - loss: 0.3502 - val_accuracy: 0.8641 - val_loss: 0.3978 - learning_rate: 2.5000e-04
# Epoch 18/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 818s 465ms/step - accuracy: 0.8815 - loss: 0.3382 - val_accuracy: 0.8618 - val_loss: 0.4286 - learning_rate: 2.5000e-04
# Epoch 19/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 4363s 2s/step - accuracy: 0.8829 - loss: 0.3337 - val_accuracy: 0.8697 - val_loss: 0.4142 - learning_rate: 2.5000e-04
# Epoch 20/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 964s 548ms/step - accuracy: 0.8861 - loss: 0.3265 - val_accuracy: 0.8786 - val_loss: 0.3741 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 20.
# 🔍 Evaluando modelo...
# ✅ Usuario 1604.0: Accuracy = 0.8770
#
# 🔄 FOLD 6/51: Usuario de test = 1605.0
# --------------------------------------------------
# 📊 Train: 62605 ventanas de 50 usuarios
# 📊 Test: 1260 ventanas del usuario 1605.0
# 🎯 Clases comunes: 8
# 🏋️ Entrenando modelo...
# Epoch 1/20
# 1761/1761 ━━━━━━━━━━━━━━━━━━━━ 1551s 873ms/step - accuracy: 0.6036 - loss: 1.0846 - val_accuracy: 0.7352 - val_loss: 0.7531 - learning_rate: 0.0010
# Epoch 2/20
# 1303/1761 ━━━━━━━━━━━━━━━━━━━━ 5:01 658ms/step - accuracy: 0.6986 - loss: 0.8371

# %%
print("🚀 Creando ventanas RAW de 250 timesteps...")

# Opción 1: Solo acelerómetro
X_accel_raw, y_accel_raw, subjects_accel, metadata_accel = create_raw_windows_250_timesteps(
    df=df_gyro,  # Tu DataFrame de acelerómetro
    window_seconds=5,
    overlap_percent=50,
    sampling_rate=20,
    target_timesteps=250
)

# Opción 2: Acelerómetro + Giroscopio (RECOMENDADO)
# X_multi_raw, y_multi_raw, subjects_multi, metadata_multi = create_raw_windows_multi_sensor(
#     df_accel=df_accel_inner,
#     df_gyro=df_gyro_inner,
#     window_seconds=5,
#     overlap_percent=50,
#     sampling_rate=20,
#     target_timesteps=250
# )

# Validar ventanas
validate_raw_windows(X_accel_raw, y_accel_raw, subjects_accel, metadata_accel)

# Preparar para entrenamiento
from sklearn.preprocessing import LabelEncoder

# Codificar etiquetas
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_accel_raw)

# División de datos
X_train, X_test, y_train, y_test = train_test_split(
    X_accel_raw, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

print(f"✅ Datos preparados:")
print(f"  X_train: {X_train.shape}")  # (n_samples, 250, 6)
print(f"  X_test: {X_test.shape}")
print(f"  Timesteps: {X_train.shape[1]}")
print(f"  Características: {X_train.shape[2]}")

# Crear y entrenar modelo
input_shape = (250, X_train.shape[2])  # (250, 6) para multi-sensor
num_classes = len(label_encoder.classes_)
# Out:
# 🚀 Creando ventanas RAW de 250 timesteps...
# 🔧 Configuración de ventanas RAW:
#   Duración: 5s
#   Timesteps objetivo: 250
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Muestras esperadas por ventana: 100
#   Paso entre ventanas: 50 muestras
# 👤 Usuario 1600.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad B: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad C: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad E: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad F: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad I: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad K: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad Q: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad R: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad S: 4175 muestras
#   ✅ Creadas 82 ventanas
# 👤 Usuario 1601.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad B: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad C: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad D: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad E: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad F: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad G: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad I: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad J: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad K: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad L: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad O: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad P: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad E: 3699 muestras
#   ✅ Creadas 72 ventanas
# 👤 Usuario 1602.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad B: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad E: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad F: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad G: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad I: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad J: 3619 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad K: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad M: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad O: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad P: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad R: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad S: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad C: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad F: 3617 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad I: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad D: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad E: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad F: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad G: 3615 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad I: 4935 muestras
#   ✅ Creadas 97 ventanas
# 👤 Usuario 1605.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad K: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad L: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad M: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad P: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad Q: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad B: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad D: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad E: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad F: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad G: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad I: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad J: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad K: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad L: 4577 muestras
#   ✅ Creadas 90 ventanas
# 👤 Usuario 1607.0, Actividad M: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad O: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad Q: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad H: 3609 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad J: 6899 muestras
#   ✅ Creadas 136 ventanas
# 👤 Usuario 1608.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad K: 6070 muestras
#   ✅ Creadas 120 ventanas
# 👤 Usuario 1609.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad M: 4053 muestras
#   ✅ Creadas 80 ventanas
# 👤 Usuario 1609.0, Actividad O: 4875 muestras
#   ✅ Creadas 96 ventanas
# 👤 Usuario 1609.0, Actividad P: 4191 muestras
#   ✅ Creadas 82 ventanas
# 👤 Usuario 1609.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad M: 3619 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad Q: 3612 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1610.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad B: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1611.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad J: 3618 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad L: 3984 muestras
#   ✅ Creadas 78 ventanas
# 👤 Usuario 1612.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1612.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad A: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad B: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad D: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad E: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad F: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad G: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad H: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad I: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad J: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad K: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad L: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad O: 3611 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad P: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad Q: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1613.0, Actividad S: 3619 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad A: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad B: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad C: 3616 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad D: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad E: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad F: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad G: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad H: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad I: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad J: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad K: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad L: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad M: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad O: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad P: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1614.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad Q: 3618 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1615.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1616.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad P: 5710 muestras
#   ✅ Creadas 113 ventanas
# 👤 Usuario 1617.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad R: 3618 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1617.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad F: 3617 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1618.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad A: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad B: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad C: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad D: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad E: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad F: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad G: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad H: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad I: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad J: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad K: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad L: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad M: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad O: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad P: 3616 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad Q: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad R: 3616 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1619.0, Actividad S: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad Q: 5907 muestras
#   ✅ Creadas 117 ventanas
# 👤 Usuario 1620.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1620.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad A: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad B: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad C: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad D: 7918 muestras
#   ✅ Creadas 157 ventanas
# 👤 Usuario 1621.0, Actividad E: 5816 muestras
#   ✅ Creadas 115 ventanas
# 👤 Usuario 1621.0, Actividad F: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad G: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad H: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad I: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad J: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad K: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad L: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad M: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad O: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad P: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad Q: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad R: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1621.0, Actividad S: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad C: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1622.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad D: 3588 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1623.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1623.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad A: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad B: 3612 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad E: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad M: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad O: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad Q: 7933 muestras
#   ✅ Creadas 157 ventanas
# 👤 Usuario 1624.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1624.0, Actividad S: 5643 muestras
#   ✅ Creadas 111 ventanas
# 👤 Usuario 1625.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad B: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad C: 3616 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad I: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad M: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad O: 5402 muestras
#   ✅ Creadas 107 ventanas
# 👤 Usuario 1625.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad Q: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1625.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad B: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad C: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad G: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad K: 6013 muestras
#   ✅ Creadas 119 ventanas
# 👤 Usuario 1626.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad M: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad O: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad Q: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1626.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad A: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad F: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad G: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad L: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad M: 3605 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad O: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1627.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad E: 9097 muestras
#   ✅ Creadas 180 ventanas
# 👤 Usuario 1628.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1628.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1629.0, Actividad A: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad B: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad C: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad D: 7208 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad E: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad F: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad G: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad H: 7238 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad I: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad J: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad K: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad L: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad M: 7204 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad O: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad P: 7204 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad Q: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad R: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1629.0, Actividad S: 7206 muestras
#   ✅ Creadas 143 ventanas
# 👤 Usuario 1630.0, Actividad A: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad B: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad M: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad O: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1630.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad A: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad B: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad M: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad O: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1631.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad C: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad I: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad J: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1632.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1633.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad H: 3618 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1634.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad H: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad M: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad Q: 3605 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1635.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad M: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad O: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1636.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1637.0, Actividad A: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad B: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad D: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad E: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad F: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad G: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad H: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad I: 4462 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad K: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad L: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad M: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad O: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad P: 4462 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad Q: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad R: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1637.0, Actividad S: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad A: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad B: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad C: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad D: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad E: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad F: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad G: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad I: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad J: 4465 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad K: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad L: 4465 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad M: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad P: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad Q: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad R: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1638.0, Actividad S: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad A: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad B: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad C: 4460 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad D: 4455 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad E: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad F: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad G: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad H: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad I: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad J: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad K: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad M: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad O: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad P: 4465 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad Q: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad R: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1639.0, Actividad S: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad A: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad B: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad D: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad F: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad G: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad H: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad I: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad J: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad K: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad L: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad M: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad O: 4463 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad P: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad Q: 4462 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad R: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1640.0, Actividad S: 4464 muestras
#   ✅ Creadas 88 ventanas
# 👤 Usuario 1641.0, Actividad A: 3610 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1641.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad C: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad D: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad E: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad F: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad H: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad I: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad K: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad L: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad P: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad Q: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad R: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1641.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad D: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad E: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad H: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad I: 3605 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1642.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad K: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad L: 6134 muestras
#   ✅ Creadas 121 ventanas
# 👤 Usuario 1642.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad P: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad R: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1642.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad A: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad B: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad C: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad D: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad E: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad H: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad K: 3612 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1643.0, Actividad L: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad M: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad O: 3611 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1643.0, Actividad P: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad R: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad C: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad D: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad E: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad H: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad K: 5870 muestras
#   ✅ Creadas 116 ventanas
# 👤 Usuario 1644.0, Actividad L: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad O: 5502 muestras
#   ✅ Creadas 109 ventanas
# 👤 Usuario 1644.0, Actividad P: 4977 muestras
#   ✅ Creadas 98 ventanas
# 👤 Usuario 1644.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad R: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad C: 5763 muestras
#   ✅ Creadas 114 ventanas
# 👤 Usuario 1645.0, Actividad D: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad E: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad G: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad H: 4307 muestras
#   ✅ Creadas 85 ventanas
# 👤 Usuario 1645.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad K: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad L: 3613 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1645.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad P: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad R: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad S: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad C: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1646.0, Actividad D: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad E: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad H: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad K: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad L: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad P: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad R: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1647.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad B: 4272 muestras
#   ✅ Creadas 84 ventanas
# 👤 Usuario 1647.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad D: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad E: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad F: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad G: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad I: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad J: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad K: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad L: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad M: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad O: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad P: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad B: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad C: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad D: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad E: 3613 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad H: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad K: 3608 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad L: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad P: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad R: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1649.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad B: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad C: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad D: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad E: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad F: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad G: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad H: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad I: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad J: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad K: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad L: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad M: 3912 muestras
#   ✅ Creadas 77 ventanas
# 👤 Usuario 1649.0, Actividad O: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad P: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1650.0, Actividad A: 5365 muestras
#   ✅ Creadas 106 ventanas
# 👤 Usuario 1650.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad C: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad D: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad E: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad F: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad G: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad H: 3613 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1650.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad K: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad L: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad P: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad R: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad S: 3599 muestras
#   ✅ Creadas 70 ventanas
#
# 📊 RESULTADO FINAL:
#   Forma de X: (67705, 250, 3)
#   Forma de y: (67705,)
#   Total ventanas: 67705
#   Usuarios únicos: 51
#   Actividades únicas: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'O', 'P', 'Q', 'R', 'S']
# 🔍 VALIDANDO VENTANAS RAW
# ========================================
# ✅ Forma de X: (67705, 250, 3)
# ✅ Timesteps por ventana: 250
# ✅ Características por timestep: 3
# ✅ Total ventanas: 67705
# ✅ Timesteps correctos: 250
#
# 📊 Distribución de actividades:
#   A: 3790 ventanas
#   B: 3696 ventanas
#   C: 3553 ventanas
#   D: 3838 ventanas
#   E: 3820 ventanas
#   F: 3683 ventanas
#   G: 3753 ventanas
#   H: 3681 ventanas
#   I: 3780 ventanas
#   J: 3730 ventanas
#   K: 3898 ventanas
#   L: 3743 ventanas
#   M: 3768 ventanas
#   O: 3695 ventanas
#   P: 3835 ventanas
#   Q: 3885 ventanas
#   R: 3753 ventanas
#   S: 3804 ventanas
#
# 📈 Rango de valores:
#   Min: -34.900
#   Max: 34.904
#   Mean: -0.014
#   Std: 1.413
# ✅ Sin valores NaN
# ✅ Datos preparados:
#   X_train: (54164, 250, 3)
#   X_test: (13541, 250, 3)
#   Timesteps: 250
#   Características: 3

# %%
model = create_cnn_lstm_model(input_shape=input_shape, num_classes=num_classes)

# Entrenar
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    callbacks=callbacks
)
