# %%
from io import StringIO

import matplotlib.pyplot as plt
from scipy.io import arff
import seaborn as sns
from loguru import logger
import yaml

from datetime import datetime
import polars as pl
import pandas as pd
import numpy as np
import sys
import os
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# MODEL
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import (
    LabelEncoder, 
    StandardScaler,
    label_binarize
)
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    accuracy_score,
    precision_recall_fscore_support,
    balanced_accuracy_score,
    roc_auc_score,
    roc_curve
)

# Save variables for model
import joblib

# PERSONAL FUNCTIONS
from utils import *
from models.main import *
# from functions.windows import create_feature_windows # creación de ventanas e ingenieria de características

# %%
def create_raw_windows_250_timesteps_robust(df, window_seconds=5, overlap_percent=50, 
                                           sampling_rate=20, target_timesteps=250,
                                           min_data_threshold=0.5, max_gap_seconds=1.0):
    """
    Versión ROBUSTA: Crea ventanas basadas en TIEMPO REAL con validación mejorada
    
    Args:
        df: DataFrame con datos de sensores (Polars o Pandas)
        window_seconds: Duración de la ventana en segundos (default: 5)
        overlap_percent: Porcentaje de solapamiento (default: 50)
        sampling_rate: Frecuencia de muestreo en Hz (default: 20)
        target_timesteps: Número objetivo de timesteps por ventana (default: 250)
        min_data_threshold: Umbral mínimo de datos válidos (0.5 = 50%)
        max_gap_seconds: Máximo gap permitido en segundos (1.0s)
        
    Returns:
        X: Array con forma (n_windows, 250, 3) - datos de ventanas
        y: Array con etiquetas de actividad
        subjects: Array con IDs de usuario
        metadata: DataFrame con información de las ventanas
    """
    
    print(f"🔧 Configuración de ventanas RAW ROBUSTA:")
    print(f"  Duración: {window_seconds}s")
    print(f"  Timesteps objetivo: {target_timesteps}")
    print(f"  Frecuencia de muestreo: {sampling_rate}Hz")
    print(f"  Solapamiento: {overlap_percent}%")
    print(f"  Umbral mínimo de datos: {min_data_threshold*100:.1f}%")
    print(f"  Máximo gap permitido: {max_gap_seconds}s")
    
    # Convertir a pandas si es necesario
    if hasattr(df, 'to_pandas'):
        df_pd = df.to_pandas()
    else:
        df_pd = df.copy()
    
    # Asegurar que Timestamp es datetime
    if df_pd['Timestamp'].dtype == 'object':
        df_pd['Timestamp'] = pd.to_datetime(df_pd['Timestamp'])
    elif df_pd['Timestamp'].dtype == 'int64':
        df_pd['Timestamp'] = pd.to_datetime(df_pd['Timestamp'])
    
    # Calcular parámetros de tiempo
    window_duration_ns = int(window_seconds * 1e9)
    step_duration_ns = int(window_duration_ns * (100 - overlap_percent) / 100)
    
    print(f"  Duración de ventana: {window_seconds}s")
    print(f"  Paso entre ventanas: {step_duration_ns / 1e9:.2f}s")
    
    # Listas para almacenar resultados
    X_windows = []
    y_labels = []
    subjects_list = []
    metadata_list = []
    
    total_windows_attempted = 0
    total_windows_created = 0
    
    # Procesar por usuario y actividad
    for (user_id, activity), group in df_pd.groupby(['Subject-id', 'Activity Label']):
        
        # Ordenar por timestamp y limpiar datos
        group = group.sort_values('Timestamp').reset_index(drop=True)
        group = group.dropna(subset=['X', 'Y', 'Z', 'Timestamp'])
        
        if len(group) < window_seconds * sampling_rate:
            print(f"⚠️ Usuario {user_id}, Actividad {activity}: Muy pocos datos ({len(group)} muestras)")
            continue
        
        # Convertir timestamps a nanosegundos
        if group['Timestamp'].dtype.name.startswith('datetime'):
            timestamps_ns = group['Timestamp'].astype('int64')
        else:
            timestamps_ns = group['Timestamp'].values
        
        print(f"👤 Usuario {user_id}, Actividad {activity}: {len(group)} muestras")
        
        # Obtener rango temporal
        start_time_ns = timestamps_ns.min()
        end_time_ns = timestamps_ns.max()
        total_duration_s = (end_time_ns - start_time_ns) / 1e9
        
        print(f"   Duración total: {total_duration_s:.1f}s")
        
        # Detectar y reportar gaps grandes
        time_diffs = np.diff(timestamps_ns) / 1e9  # Convertir a segundos
        large_gaps = time_diffs > max_gap_seconds
        if np.any(large_gaps):
            n_gaps = np.sum(large_gaps)
            max_gap = np.max(time_diffs)
            print(f"   ⚠️ Detectados {n_gaps} gaps > {max_gap_seconds}s (máximo: {max_gap:.1f}s)")
        
        # Crear ventanas deslizantes
        window_count = 0
        current_start_ns = start_time_ns
        
        while current_start_ns + window_duration_ns <= end_time_ns:
            total_windows_attempted += 1
            current_end_ns = current_start_ns + window_duration_ns
            
            # Filtrar datos en esta ventana temporal
            window_mask = (
                (timestamps_ns >= current_start_ns) & 
                (timestamps_ns < current_end_ns)
            )
            window_data_df = group[window_mask]
            
            # Validación de ventana
            is_valid, validation_info = validate_window_data(
                window_data_df, 
                window_seconds, 
                sampling_rate, 
                min_data_threshold,
                max_gap_seconds
            )
            
            if is_valid:
                # Extraer datos de sensores
                sensor_data = window_data_df[['X', 'Y', 'Z']].values
                window_timestamps = window_data_df['Timestamp'].values
                
                try:
                    # Redimensionar/interpolar a target_timesteps
                    resampled_window = resample_window_robust(
                        sensor_data, window_timestamps, target_timesteps, window_seconds
                    )
                    
                    # Verificar calidad final
                    if is_window_quality_good(resampled_window):
                        # Guardar datos
                        X_windows.append(resampled_window)
                        y_labels.append(activity)
                        subjects_list.append(user_id)
                        
                        # Metadata extendida
                        metadata_list.append({
                            'Subject-id': user_id,
                            'Activity Label': activity,
                            'window_start': pd.to_datetime(current_start_ns),
                            'window_end': pd.to_datetime(current_end_ns),
                            'original_samples': len(window_data_df),
                            'resampled_timesteps': target_timesteps,
                            'window_idx': window_count,
                            'actual_duration_s': window_seconds,
                            'data_coverage': validation_info['data_coverage'],
                            'max_gap_s': validation_info['max_gap'],
                            'sampling_rate_actual': validation_info['actual_rate']
                        })
                        
                        window_count += 1
                        total_windows_created += 1
                    else:
                        print(f"   ❌ Ventana {window_count}: Calidad de datos insuficiente después de interpolación")
                
                except Exception as e:
                    print(f"   ❌ Ventana {window_count}: Error en interpolación - {str(e)}")
            
            else:
                # No mostrar warning para cada ventana inválida, solo resumen
                pass
            
            # Mover al siguiente inicio de ventana
            current_start_ns += step_duration_ns
        
        print(f"  ✅ Creadas {window_count} ventanas válidas")
    
    # Resumen final
    print(f"\n📊 RESUMEN DE VALIDACIÓN:")
    print(f"  Ventanas intentadas: {total_windows_attempted}")
    print(f"  Ventanas creadas: {total_windows_created}")
    print(f"  Tasa de éxito: {(total_windows_created/total_windows_attempted)*100:.1f}%")
    
    # Convertir a arrays numpy
    if len(X_windows) > 0:
        X = np.array(X_windows)
        y = np.array(y_labels)
        subjects = np.array(subjects_list)
        metadata_df = pd.DataFrame(metadata_list)
        
        print(f"\n📊 RESULTADO FINAL (ROBUSTO):")
        print(f"  Forma de X: {X.shape}")
        print(f"  Forma de y: {y.shape}")
        print(f"  Total ventanas: {len(X)}")
        print(f"  Usuarios únicos: {len(np.unique(subjects))}")
        print(f"  Actividades únicas: {sorted(np.unique(y))}")
        
        return X, y, subjects, metadata_df
    
    else:
        print("❌ No se crearon ventanas válidas")
        return None, None, None, None


def validate_window_data(window_data_df, window_seconds, sampling_rate, 
                        min_data_threshold, max_gap_seconds):
    """
    Valida si una ventana de datos es aceptable
    
    Returns:
        bool: True si la ventana es válida
        dict: Información de validación
    """
    if len(window_data_df) == 0:
        return False, {'reason': 'empty', 'data_coverage': 0, 'max_gap': float('inf'), 'actual_rate': 0}
    
    # Calcular cobertura de datos esperada
    expected_samples = window_seconds * sampling_rate
    actual_samples = len(window_data_df)
    data_coverage = actual_samples / expected_samples
    
    # Si hay muy pocos datos
    if data_coverage < min_data_threshold:
        return False, {
            'reason': 'insufficient_data', 
            'data_coverage': data_coverage,
            'max_gap': float('inf'),
            'actual_rate': 0
        }
    
    # Calcular gaps en los datos
    if len(window_data_df) > 1:
        timestamps = pd.to_datetime(window_data_df['Timestamp'])
        time_diffs = timestamps.diff().dt.total_seconds().fillna(0)
        max_gap = time_diffs.max()
        actual_rate = len(window_data_df) / (timestamps.max() - timestamps.min()).total_seconds()
    else:
        max_gap = 0
        actual_rate = sampling_rate
    
    # Si hay gaps muy grandes
    if max_gap > max_gap_seconds:
        return False, {
            'reason': 'large_gap', 
            'data_coverage': data_coverage,
            'max_gap': max_gap,
            'actual_rate': actual_rate
        }
    
    # Verificar que no hay valores NaN o infinitos en los sensores
    sensor_data = window_data_df[['X', 'Y', 'Z']].values
    if np.any(np.isnan(sensor_data)) or np.any(np.isinf(sensor_data)):
        return False, {
            'reason': 'invalid_values',
            'data_coverage': data_coverage,
            'max_gap': max_gap,
            'actual_rate': actual_rate
        }
    
    return True, {
        'reason': 'valid',
        'data_coverage': data_coverage,
        'max_gap': max_gap,
        'actual_rate': actual_rate
    }


def resample_window_robust(sensor_data, timestamps, target_timesteps, window_seconds):
    """
    Versión robusta de remuestreo con múltiples estrategias
    """
    from scipy.interpolate import interp1d
    from scipy import signal
    
    if len(sensor_data) == 0:
        return np.zeros((target_timesteps, 3))
    
    original_timesteps = len(sensor_data)
    
    if original_timesteps == target_timesteps:
        return sensor_data.copy()
    
    if original_timesteps == 1:
        return np.tile(sensor_data[0], (target_timesteps, 1))
    
    try:
        # Estrategia 1: Interpolación temporal precisa
        if hasattr(timestamps[0], 'timestamp'):
            time_seconds = np.array([t.timestamp() for t in timestamps])
        elif isinstance(timestamps[0], pd.Timestamp):
            time_seconds = np.array([t.timestamp() for t in timestamps])
        else:
            time_seconds = timestamps.astype('int64') / 1e9
        
        # Normalizar tiempos
        time_min = time_seconds.min()
        time_max = time_seconds.max()
        
        if time_max > time_min:
            relative_times = (time_seconds - time_min) / (time_max - time_min)
        else:
            relative_times = np.linspace(0, 1, len(time_seconds))
        
        # Crear tiempos objetivo uniformes
        target_times = np.linspace(0, 1, target_timesteps)
        
        # Interpolar cada eje
        resampled_data = np.zeros((target_timesteps, 3))
        
        for axis in range(3):
            try:
                # Estrategia de interpolación según la cantidad de datos
                if original_timesteps >= target_timesteps:
                    # Downsample: usar signal.resample para preservar características
                    resampled_axis = signal.resample(sensor_data[:, axis], target_timesteps)
                else:
                    # Upsample: usar interpolación
                    if len(np.unique(relative_times)) > 1:
                        interpolator = interp1d(
                            relative_times, 
                            sensor_data[:, axis],
                            kind='cubic' if original_timesteps >= 4 else 'linear',
                            bounds_error=False,
                            fill_value='extrapolate'
                        )
                        resampled_axis = interpolator(target_times)
                    else:
                        resampled_axis = np.full(target_timesteps, sensor_data[0, axis])
                
                resampled_data[:, axis] = resampled_axis
                
            except Exception as e:
                # Fallback: interpolación lineal simple
                resampled_data[:, axis] = np.interp(
                    target_times, relative_times, sensor_data[:, axis]
                )
        
        return resampled_data
    
    except Exception as e:
        print(f"Error en remuestreo robusto: {str(e)}")
        # Último fallback: replicar la primera muestra
        return np.tile(sensor_data[0], (target_timesteps, 1))


def is_window_quality_good(resampled_window, max_std_threshold=50.0):
    """
    Verifica la calidad final de una ventana remuestreada
    """
    # Verificar NaN o infinitos
    if np.any(np.isnan(resampled_window)) or np.any(np.isinf(resampled_window)):
        return False
    
    # Verificar valores extremos (posibles errores de interpolación)
    if np.any(np.abs(resampled_window) > 1000):  # Ajustar según tus datos
        return False
    
    # Verificar varianza (datos demasiado planos pueden indicar error)
    for axis in range(resampled_window.shape[1]):
        std_axis = np.std(resampled_window[:, axis])
        if std_axis > max_std_threshold:  # Varianza excesiva
            return False
        if std_axis < 0.001:  # Datos demasiado planos
            return False
    
    return True

# %%
def loso_cross_validation_raw_windows_robust(df_accel, df_gyro=None, model_architecture_func=None,
                                           window_seconds=5, overlap_percent=50, 
                                           sampling_rate=20, target_timesteps=250,
                                           epochs=30, batch_size=32, verbose=1, 
                                           save_results=True, results_path="loso_raw_windows"):
    """LOSO con validación robusta de ventanas"""
    
    print("🚀 INICIANDO LOSO CROSS-VALIDATION - VENTANAS RAW ROBUSTAS")
    print("=" * 70)
    
    # Usar la función robusta para crear ventanas
    X_all, y_all, subjects_all, metadata_all = create_raw_windows_250_timesteps_robust(
        df=df_accel,
        window_seconds=window_seconds,
        overlap_percent=overlap_percent,
        sampling_rate=sampling_rate,
        target_timesteps=target_timesteps,
        min_data_threshold=0.6,  # 60% mínimo de datos
        max_gap_seconds=1.0      # Máximo 1 segundo de gap
    )
    
    if X_all is None:
        print("❌ No se pudieron crear ventanas válidas")
        return None
    
    # Obtener usuarios únicos
    users = np.unique(subjects_all)
    n_users = len(users)
    
    print(f"👥 Total de usuarios: {n_users}")
    print(f"📊 Usuarios: {users}")
    print(f"📊 Forma de datos: {X_all.shape}")
    
    # Preparar label encoder global
    from sklearn.preprocessing import LabelEncoder
    global_label_encoder = LabelEncoder()
    y_all_encoded = global_label_encoder.fit_transform(y_all)
    
    # Almacenar resultados
    loso_results = {
        'user': [],
        'accuracy': [],
        'precision_macro': [],
        'recall_macro': [],
        'f1_macro': [],
        'confusion_matrix': [],
        'classification_report': [],
        'train_windows': [],
        'test_windows': [],
        'y_true': [],
        'y_pred': []
    }
    
    all_y_true = []
    all_y_pred = []
    
    # Iterar sobre cada usuario (LOSO)
    for i, test_user in enumerate(users):
        print(f"\n🔄 FOLD {i+1}/{n_users}: Usuario de test = {test_user}")
        print("-" * 50)
        
        # División de datos: un usuario para test, resto para train
        train_mask = subjects_all != test_user
        test_mask = subjects_all == test_user
        
        X_train = X_all[train_mask]
        y_train = y_all_encoded[train_mask]
        X_test = X_all[test_mask]
        y_test = y_all_encoded[test_mask]
        
        print(f"📊 Train: {len(X_train)} ventanas de {len(np.unique(subjects_all[train_mask]))} usuarios")
        print(f"📊 Test: {len(X_test)} ventanas del usuario {test_user}")
        
        # Verificar que hay suficientes datos
        if len(X_train) < 50 or len(X_test) < 10:
            print(f"⚠️ Datos insuficientes para usuario {test_user}, saltando...")
            continue
        
        # Verificar clases en común
        train_classes = set(np.unique(y_train))
        test_classes = set(np.unique(y_test))
        common_classes = train_classes.intersection(test_classes)
        
        if len(common_classes) < 2:
            print(f"⚠️ Muy pocas clases comunes para usuario {test_user}, saltando...")
            continue
        
        print(f"🎯 Clases comunes: {len(common_classes)}")
        
        try:
            # Crear y compilar modelo
            input_shape = (target_timesteps, X_train.shape[2])
            num_classes = len(global_label_encoder.classes_)
            
            if model_architecture_func is None:
                model = create_cnn_lstm_model(input_shape=input_shape, num_classes=num_classes)
            else:
                model = model_architecture_func(input_shape=input_shape, num_classes=num_classes)
            
            # Entrenar modelo
            print(f"🏋️ Entrenando modelo...")
            history = model.fit(
                X_train, y_train,
                epochs=epochs,
                batch_size=batch_size,
                callbacks=callbacks,
                verbose=0 if verbose == 0 else 1,
                validation_split=0.1
            )
            
            # Evaluar modelo
            print(f"🔍 Evaluando modelo...")
            y_pred = model.predict(X_test, verbose=0)
            y_pred_classes = np.argmax(y_pred, axis=1)
            
            # Calcular métricas
            from sklearn.metrics import accuracy_score, precision_recall_fscore_support
            from sklearn.metrics import classification_report, confusion_matrix
            
            accuracy = accuracy_score(y_test, y_pred_classes)
            precision, recall, f1, _ = precision_recall_fscore_support(
                y_test, y_pred_classes, average='macro', zero_division=0
            )
            
            # Reporte de clasificación
            report = classification_report(
                y_test, y_pred_classes,
                target_names=global_label_encoder.classes_,
                output_dict=True,
                zero_division=0
            )
            
            # Matriz de confusión
            cm = confusion_matrix(y_test, y_pred_classes)
            
            # Guardar resultados
            loso_results['user'].append(test_user)
            loso_results['accuracy'].append(accuracy)
            loso_results['precision_macro'].append(precision)
            loso_results['recall_macro'].append(recall)
            loso_results['f1_macro'].append(f1)
            loso_results['confusion_matrix'].append(cm)
            loso_results['classification_report'].append(report)
            loso_results['train_windows'].append(len(X_train))
            loso_results['test_windows'].append(len(X_test))
            loso_results['y_true'].append(y_test)
            loso_results['y_pred'].append(y_pred_classes)
            
            # Acumular para métricas globales
            all_y_true.extend(y_test)
            all_y_pred.extend(y_pred_classes)
            
            print(f"✅ Usuario {test_user}: Accuracy = {accuracy:.4f}")
            
        except Exception as e:
            print(f"❌ Error con usuario {test_user}: {str(e)}")
            continue
    
    # Calcular métricas agregadas
    print(f"\n📊 RESULTADOS LOSO RAW WINDOWS")
    print("=" * 70)
    
    if len(loso_results['accuracy']) > 0:
        mean_accuracy = np.mean(loso_results['accuracy'])
        std_accuracy = np.std(loso_results['accuracy'])
        mean_precision = np.mean(loso_results['precision_macro'])
        mean_recall = np.mean(loso_results['recall_macro'])
        mean_f1 = np.mean(loso_results['f1_macro'])
        
        print(f"🎯 Accuracy promedio: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
        print(f"🎯 Precision promedio: {mean_precision:.4f}")
        print(f"🎯 Recall promedio: {mean_recall:.4f}")
        print(f"🎯 F1-Score promedio: {mean_f1:.4f}")
        print(f"📊 Usuarios evaluados: {len(loso_results['accuracy'])}/{n_users}")
        
        # Guardar resultados
        if save_results:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            
            results_df = pd.DataFrame({
                'user': loso_results['user'],
                'accuracy': loso_results['accuracy'],
                'precision_macro': loso_results['precision_macro'],
                'recall_macro': loso_results['recall_macro'],
                'f1_macro': loso_results['f1_macro'],
                'train_windows': loso_results['train_windows'],
                'test_windows': loso_results['test_windows']
            })
            
            results_df.to_csv(f"{results_path}_summary_{timestamp}.csv", index=False)
            joblib.dump(loso_results, f"{results_path}_complete_{timestamp}.joblib")
            
            print(f"💾 Resultados guardados: {results_path}_*_{timestamp}.*")
        
        return {
            'summary': results_df,
            'mean_accuracy': mean_accuracy,
            'std_accuracy': std_accuracy,
            'mean_precision': mean_precision,
            'mean_recall': mean_recall,
            'mean_f1': mean_f1,
            'detailed_results': loso_results,
            'global_label_encoder': global_label_encoder
        }
    
    else:
        print("❌ No se pudieron evaluar usuarios")
        return None

# %%
# Cargar datos
path_base = r"F:\UPC\Tesis\HARbit-Model\src\data\wisdm-dataset\raw\watch"
sensor_data = load_sensors_separately(path_base)
df_gyro = sensor_data['gyro']
# df_gyro = df_gyro.rename({'X': 'X_gyro', 'Y': 'Y_gyro', 'Z': 'Z_gyro'})

df_accel = sensor_data['accel']
# df_accel = df_accel.rename({'X': 'X_accel', 'Y': 'Y_accel', 'Z': 'Z_accel'})

print(f"Giroscopio: {len(df_gyro)} muestras")
print(f"Acelerómetro: {len(df_accel)} muestras")
# Out:
# 2025-09-22 22:44:51.613 | INFO     | utils.data_loading:load_sensors_separately:64 - Cargando datos de gyro...
# 2025-09-22 22:44:57.868 | INFO     | utils.data_loading:load_sensors_separately:64 - Cargando datos de accel...
# Giroscopio: 3440341 muestras
# Acelerómetro: 3777045 muestras

# %%
with open(r'F:\UPC\Tesis\HARbit-Model\src\config\activities.yaml', 'r') as file:
    config = yaml.safe_load(file)['config']

# %%
activities_ = config['labels']
cluster_ = config['clusters']

df_gyro = df_gyro.to_pandas()
df_accel = df_accel.to_pandas()

df_gyro['Activity Label']   = df_gyro['Activity Label'].apply(lambda x: activities_[x])
df_accel['Activity Label']  = df_accel['Activity Label'].apply(lambda x: activities_[x])

for activity in cluster_.keys():
    for act in cluster_[activity]:
        df_gyro.loc[df_gyro['Activity Label'] == act, 'Activity Label'] = activity
        df_accel.loc[df_accel['Activity Label'] == act, 'Activity Label'] = activity

# %%
# Primero, diagnostica tus datos
print("🔍 Diagnosticando datos de timestamp...")
diagnose_timestamp_data(df_accel)
# Out:
# 🔍 Diagnosticando datos de timestamp...
# 🔍 DIAGNÓSTICO DE TIMESTAMPS
# ==================================================
# 📊 Muestra de 1000 registros
# 📊 Tipo de Timestamp: datetime64[ns]
# 📊 Primeros valores:
#    1: 1970-01-02 01:07:06.757696641
#    2: 1970-01-02 01:07:06.807196641
#    3: 1970-01-02 01:07:06.856696641
#    4: 1970-01-02 01:07:06.906196641
#    5: 1970-01-02 01:07:06.955696641
# 👤 Usuario 1600.0, Walk:
#    Duración: 1000 muestras
#    Diferencia mediana: 0.0499s
#    Frecuencia estimada: 20.0Hz
#      Subject-id Activity Label                     Timestamp          X  \
# 0        1600.0           Walk 1970-01-02 01:07:06.757696641   4.972757
# 1        1600.0           Walk 1970-01-02 01:07:06.807196641   3.253720
# 2        1600.0           Walk 1970-01-02 01:07:06.856696641   2.801216
# 3        1600.0           Walk 1970-01-02 01:07:06.906196641   3.770868
# 4        1600.0           Walk 1970-01-02 01:07:06.955696641   4.661511
# ..          ...            ...                           ...        ...
# 995      1600.0           Walk 1970-01-02 01:07:56.363303321  19.761143
# 996      1600.0           Walk 1970-01-02 01:07:56.413216171  19.761143
# 997      1600.0           Walk 1970-01-02 01:07:56.463129021  13.608643
# 998      1600.0           Walk 1970-01-02 01:07:56.513041871  11.190498
# 999      1600.0           Walk 1970-01-02 01:07:56.562954721   8.025364
#
#             Y         Z
# 0   -0.158317  6.696732
# 1   -0.191835  6.107758
# 2   -0.155922  5.997625
# 3   -1.051354  7.731027
# 4    0.169689  9.684695
# ..        ...       ...
# 995  3.011607 -3.804237
# 996  2.741062 -4.364480
# 997 -1.566107 -1.094001
# 998 -2.159869  0.218022
# 999 -0.986710 -1.345392
#
# [1000 rows x 6 columns]

# %%
# Luego ejecuta el LOSO corregido
print("\n🚀 Ejecutando LOSO con ventanas RAW CORREGIDAS...")

# Ejecutar LOSO con la función corregida
loso_results = loso_cross_validation_raw_windows_robust(
    df_accel=df_accel,
    df_gyro=None,
    model_architecture_func=create_cnn_lstm_model,
    window_seconds=5,
    overlap_percent=50,
    sampling_rate=20,
    target_timesteps=250,
    epochs=20,
    batch_size=32,
    verbose=1,
    save_results=True,
    results_path="loso_raw_robust"
)

# Mostrar resultados
if loso_results:
    print(f"✅ LOSO RAW completado!")
    print(f"📊 Accuracy promedio: {loso_results['mean_accuracy']:.4f}")
    print(f"📊 Std Accuracy: {loso_results['std_accuracy']:.4f}")
else:
    print("❌ LOSO falló - revisa los datos")
# Out:
# 🚀 Ejecutando LOSO con ventanas RAW CORREGIDAS...
# 🚀 INICIANDO LOSO CROSS-VALIDATION - VENTANAS RAW ROBUSTAS
# ======================================================================
# 🔧 Configuración de ventanas RAW ROBUSTA:
#   Duración: 5s
#   Timesteps objetivo: 250
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   
)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1615.0, Actividad Workouts: 10815 muestras
#    Duración total: 10147.4s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 9571.7s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1615.0, Actividad Write: 3620 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad Eat: 18025 muestras
#    Duración total: 1101.2s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 66.9s)
#   ✅ Creadas 358 ventanas válidas
# 👤 Usuario 1616.0, Actividad Others: 10815 muestras
#    Duración total: 854.5s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 278.8s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1616.0, Actividad Sit: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1616.0, Actividad Walk: 7210 muestras
#    Duración total: 1321.2s
#    ⚠️ Detectados 1 gaps > 1.0s (máximo: 961.4s)
#   ✅ Creadas 142 ventanas válidas
# 👤 Usuario 1616.0, Actividad Workouts: 10815 muestras
#    Duración total: 650.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 70.3s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1616.0, Actividad Write: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad Eat: 18025 muestras
#    Duración total: 1131.7s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 114.2s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1617.0, Actividad Others: 10830 muestras
#    Duración total: 812.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 234.9s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1617.0, Actividad Sit: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1617.0, Actividad Walk: 10815 muestras
#    Duración total: 624.2s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 54.7s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1617.0, Actividad Workouts: 12922 muestras
#    Duración total: 601.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 33.3s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1617.0, Actividad Write: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad Eat: 18025 muestras
#    Duración total: 1735.3s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 481.7s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1618.0, Actividad Others: 10815 muestras
#    Duración total: 2171.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 918.3s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1618.0, Actividad Sit: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad Type: 3619 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1618.0, Actividad Walk: 10814 muestras
#    Duración total: 96212.0s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 95636.8s)
#   ✅ Creadas 212 ventanas válidas
# 👤 Usuario 1618.0, Actividad Workouts: 7210 muestras
#    Duración total: 405.7s
#    ⚠️ Detectados 1 gaps > 1.0s (máximo: 45.9s)
#   ✅ Creadas 142 ventanas válidas
# 👤 Usuario 1618.0, Actividad Write: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad Eat: 18010 muestras
#    Duración total: 1088.2s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 61.4s)
#   ✅ Creadas 356 ventanas válidas
# 👤 Usuario 1619.0, Actividad Others: 10822 muestras
#    Duración total: 1106.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 498.3s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1619.0, Actividad Sit: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad Stand: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad Type: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1619.0, Actividad Walk: 10806 muestras
#    Duración total: 655.0s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 81.2s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1619.0, Actividad Workouts: 10822 muestras
#    Duración total: 618.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 41.6s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1619.0, Actividad Write: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad Eat: 18025 muestras
#    Duración total: 1782.4s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 510.6s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1620.0, Actividad Others: 10815 muestras
#    Duración total: 1859.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1030.9s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1620.0, Actividad Sit: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1620.0, Actividad Walk: 10815 muestras
#    Duración total: 1465.1s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 883.4s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1620.0, Actividad Workouts: 10815 muestras
#    Duración total: 647.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 63.0s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1620.0, Actividad Write: 5909 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad Eat: 18010 muestras
#    Duración total: 1773.3s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 511.3s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1621.0, Actividad Others: 10808 muestras
#    Duración total: 1880.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1053.8s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1621.0, Actividad Sit: 7920 muestras
#    Duración total: 180.1s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1621.0, Actividad Stand: 5818 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad Type: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1621.0, Actividad Walk: 10806 muestras
#    Duración total: 1463.1s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 886.9s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1621.0, Actividad Workouts: 10806 muestras
#    Duración total: 678.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 74.6s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1621.0, Actividad Write: 3602 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad Eat: 18025 muestras
#    Duración total: 1187.6s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 160.1s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1622.0, Actividad Others: 10815 muestras
#    Duración total: 2560.1s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1720.6s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1622.0, Actividad Sit: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1622.0, Actividad Walk: 10816 muestras
#    Duración total: 1303.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 740.3s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1622.0, Actividad Workouts: 10815 muestras
#    Duración total: 625.2s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 43.8s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1622.0, Actividad Write: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad Eat: 18025 muestras
#    Duración total: 1285.0s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 160.2s)
#   ✅ Creadas 355 ventanas válidas
# 👤 Usuario 1623.0, Actividad Others: 10815 muestras
#    Duración total: 1061.6s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 477.6s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1623.0, Actividad Sit: 3590 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1623.0, Actividad Walk: 10815 muestras
#    Duración total: 727.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo:
4s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1631.0, Actividad Workouts: 10819 muestras
#    Duración total: 602.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 32.0s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1631.0, Actividad Write: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1632.0, Actividad Eat: 18027 muestras
#    Duración total: 1659.4s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 531.5s)
#   ✅ Creadas 358 ventanas válidas
# 👤 Usuario 1632.0, Actividad Others: 10815 muestras
#    Duración total: 1501.6s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 928.5s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1632.0, Actividad Sit: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1632.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1632.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1632.0, Actividad Walk: 10815 muestras
#    Duración total: 808.5s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 239.3s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1632.0, Actividad Workouts: 10815 muestras
#    Duración total: 632.2s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 47.2s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1632.0, Actividad Write: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1633.0, Actividad Eat: 18025 muestras
#    Duración total: 1128.9s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 89.0s)
#   ✅ Creadas 356 ventanas válidas
# 👤 Usuario 1633.0, Actividad Others: 10815 muestras
#    Duración total: 2295.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1721.5s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1633.0, Actividad Sit: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1633.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1633.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1633.0, Actividad Walk: 10815 muestras
#    Duración total: 1674.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 984.4s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1633.0, Actividad Workouts: 10815 muestras
#    Duración total: 641.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 69.9s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1633.0, Actividad Write: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1634.0, Actividad Eat: 18040 muestras
#    Duración total: 1070.4s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 74.2s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1634.0, Actividad Others: 10815 muestras
#    Duración total: 597.3s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 29.0s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1634.0, Actividad Sit: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1634.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1634.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1634.0, Actividad Walk: 10815 muestras
#    Duración total: 629.6s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 62.9s)
#   ✅ Creadas 212 ventanas válidas
# 👤 Usuario 1634.0, Actividad Workouts: 10816 muestras
#    Duración total: 611.6s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 36.1s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1634.0, Actividad Write: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1635.0, Actividad Eat: 18026 muestras
#    Duración total: 1713.6s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 480.8s)
#   ✅ Creadas 358 ventanas válidas
# 👤 Usuario 1635.0, Actividad Others: 10815 muestras
#    Duración total: 1272.1s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 697.1s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1635.0, Actividad Sit: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1635.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1635.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1635.0, Actividad Walk: 10815 muestras
#    Duración total: 1468.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 902.3s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1635.0, Actividad Workouts: 10815 muestras
#    Duración total: 612.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 39.8s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1635.0, Actividad Write: 3607 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1636.0, Actividad Eat: 18025 muestras
#    Duración total: 1018.3s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 31.3s)
#   ✅ Creadas 356 ventanas válidas
# 👤 Usuario 1636.0, Actividad Others: 10815 muestras
#    Duración total: 612.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 43.7s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1636.0, Actividad Sit: 3605 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1636.0, Actividad Stand: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1636.0, Actividad Type: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1636.0, Actividad Walk: 10815 muestras
#    Duración total: 626.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 61.1s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1636.0, Actividad Workouts: 10817 muestras
#    Duración total: 600.2s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 32.7s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1636.0, Actividad Write: 3605 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1637.0, Actividad Eat: 35728 muestras
#    Duración total: 977.0s
#    ⚠️ Detectados 3 gaps > 1.0s (máximo: 144.1s)
#   ✅ Creadas 290 ventanas válidas
# 👤 Usuario 1637.0, Actividad Others: 26796 muestras
#    Duración total: 2441.6s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1813.9s)
#   ✅ Creadas 216 ventanas válidas
# 👤 Usuario 1637.0, Actividad Sit: 8934 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1637.0, Actividad Stand: 8933 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1637.0, Actividad Type: 8930 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1637.0, Actividad Walk: 26795 muestras
#    Duración total: 1463.5s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 892.8s)
#   ✅ Creadas 217 ventanas válidas
# 👤 Usuario 1637.0, Actividad Workouts: 26795 muestras
#    Duración total: 610.3s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 35.3s)
#   ✅ Creadas 217 ventanas válidas
# 👤 Usuario 1637.0, Actividad Write: 8933 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1638.0, Actividad Eat: 44662 muestras
#    Duración total: 1175.6s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 125.8s)
#   ✅ Creadas 363 ventanas válidas
# 👤 Usuario 1638.0, Actividad Others: 26794 muestras
#    Duración total: 2457.3s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1340.1s)
#   ✅ Creadas 216 ventanas válidas
# 👤 Usuario 1638.0, Actividad Sit: 8935 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1638.0, Actividad Stand: 8932 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1638.0, Actividad Type: 8935 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1638.0, Actividad Walk: 26805 muestras
#    Duración total: 1660.1s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1063.2s)
#   ✅ Creadas 217 ventanas válidas
# 👤 Usuario 1638.0, Actividad Workouts: 26803 muestras
#    Duración total: 631.3s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 48.7s)
#   ✅ Creadas 218 ventanas válidas
# 👤 Usuario 1638.0, Actividad Write: 8933 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1639.0, Actividad Eat: 35731 muestras
#    Duración total: 1083.0s
#    ⚠️ Detectados 3 gaps > 1.0s (máximo: 279.2s)
#   ✅ Creadas 290 ventanas válidas
# 👤 Usuario 1639.0, Actividad Others: 26796 muestras
#    Duración total: 1808.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1207.3s)
#   ✅ Creadas 216 ventanas válidas
# 👤 Usuario 1639.0, Actividad Sit: 8931 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1639.0, Actividad Stand: 8932 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1639.0, Actividad Type: 8933 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1639.0, Actividad Walk: 26795 muestras
#    Duración total: 1708.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1044.8s)
#   ✅ Creadas 217 ventanas válidas
# 👤 Usuario 1639.0, Actividad Workouts: 26796 muestras
#    Duración total: 708.6s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 104.6s)
#   ✅ Creadas 217 ventanas válidas
# 👤 Usuario 1639.0, Actividad Write: 8932 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1640.0, Actividad Eat: 44658 muestras
#    Duración total: 1025.5s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 39.7s)
#   ✅ Creadas 363 ventanas válidas
# 👤 Usuario 1640.0, Actividad Others: 26797 muestras
#    Duración total: 626.2s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 44.6s)
#   ✅ Creadas 217 ventanas válidas
# 👤 Usuario 1640.0, Actividad Sit: 8934 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1640.0, Actividad Stand: 8934 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1640.0, Actividad Type: 8933 muestras
#    Duración total: 180.0s
#   ✅ Creadas 71 ventanas válidas
# 👤 Usuario 1640.0, Actividad Walk: 26800 muestras
#    Duración total: 672.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 81.6s)
#   ✅ Creadas 217 ventanas válidas
# 👤 Usuario 1640.0, Actividad Workouts: 26799 muestras
#    Duración total: 627.4s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 52.0s)
#   ✅ Creadas 216 ventanas válidas
# 👤 Usuario 1640.0, Actividad Write: 8933 muestras
#    Duración total: 180.0s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1641.0, Actividad Eat: 18002 muestras
#    Duración total: 1032.3s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 40.9s)
#   ✅ Creadas 355 ventanas válidas
# 👤 Usuario 1641.0, Actividad Others: 10800 muestras
#    Duración total: 615.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 44.5s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1641.0, Actividad Sit: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1641.0, Actividad Stand: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1641.0, Actividad Type: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1641.0, Actividad Walk: 10813 muestras
#    Duración total: 838.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 271.1s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1641.0, Actividad Workouts: 10803 muestras
#    Duración total: 636.4s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 54.9s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1641.0, Actividad Write: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1642.0, Actividad Eat: 20549 muestras
#    Duración total: 1754.7s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 322.6s)
#   ✅ Creadas 356 ventanas válidas
# 👤 Usuario 1642.0, Actividad Others: 10800 muestras
#    Duración total: 1917.4s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1335.4s)
#   ✅ Creadas 212 ventanas válidas
# 👤 Usuario 1642.0, Actividad Sit: 3601 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1642.0, Actividad Stand: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1642.0, Actividad Walk: 7202 muestras
#    Duración total: 384.2s
#    ⚠️ Detectados 1 gaps > 1.0s (máximo: 24.5s)
#   ✅ Creadas 142 ventanas válidas
# 👤 Usuario 1642.0, Actividad Workouts: 10803 muestras
#    Duración total: 612.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 46.1s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1642.0, Actividad Write: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1643.0, Actividad Eat: 18014 muestras
#    Duración total: 1038.2s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 45.2s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1643.0, Actividad Others: 10800 muestras
#    Duración total: 602.1s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 33.5s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1643.0, Actividad Sit: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1643.0, Actividad Stand: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1643.0, Actividad Type: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1643.0, Actividad Walk: 10800 muestras
#    Duración total: 650.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 79.7s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1643.0, Actividad Workouts: 10813 muestras
#    Duración total: 607.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 43.2s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1643.0, Actividad Write: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1644.0, Actividad Eat: 20272 muestras
#    Duración total: 1021.1s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 35.1s)
#   ✅ Creadas 358 ventanas válidas
# 👤 Usuario 1644.0, Actividad Others: 10800 muestras
#    Duración total: 602.3s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 32.7s)
#   ✅ Creadas 212 ventanas válidas
# 👤 Usuario 1644.0, Actividad Sit: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1644.0, Actividad Stand: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1644.0, Actividad Type: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1644.0, Actividad Walk: 10802 muestras
#    Duración total: 1397.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 825.2s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1644.0, Actividad Workouts: 14084 muestras
#    Duración total: 616.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 54.0s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1644.0, Actividad Write: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1645.0, Actividad Eat: 18723 muestras
#    Duración total: 1032.5s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 49.7s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1645.0, Actividad Others: 10803 muestras
#    Duración total: 625.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 55.4s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1645.0, Actividad Sit: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1645.0, Actividad Stand: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1645.0, Actividad Type: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1645.0, Actividad Walk: 12967 muestras
#    Duración total: 746.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 181.3s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1645.0, Actividad Workouts: 10802 muestras
#    Duración total: 611.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 44.5s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1645.0, Actividad Write: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1646.0, Actividad Eat: 18000 muestras
#    Duración total: 1042.7s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 38.6s)
#   ✅ Creadas 356 ventanas válidas
# 👤 Usuario 1646.0, Actividad Others: 10801 muestras
#    Duración total: 1962.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 1105.9s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1646.0, Actividad Sit: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1646.0, Actividad Stand: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1646.0, Actividad Type: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1646.0, Actividad Walk: 10804 muestras
#    Duración total: 1417.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 855.5s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1646.0, Actividad Workouts: 10803 muestras
#    Duración total: 586.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 24.1s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1646.0, Actividad Write: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1647.0, Actividad Eat: 18019 muestras
#    Duración total: 1062.3s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 43.0s)
#   ✅ Creadas 354 ventanas válidas
# 👤 Usuario 1647.0, Actividad Others: 10809 muestras
#    Duración total: 613.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 41.1s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1647.0, Actividad Sit: 3603 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1647.0, Actividad Stand: 3604 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1647.0, Actividad Type: 3604 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1647.0, Actividad Walk: 11472 muestras
#    Duración total: 831.5s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 265.9s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1647.0, Actividad Workouts: 10812 muestras
#    Duración total: 644.3s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 67.4s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1647.0, Actividad Write: 3603 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1648.0, Actividad Eat: 18011 muestras
#    Duración total: 1135.1s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 99.7s)
#   ✅ Creadas 358 ventanas válidas
# 👤 Usuario 1648.0, Actividad Others: 10800 muestras
#    Duración total: 1355.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 497.9s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1648.0, Actividad Sit: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1648.0, Actividad Stand: 3615 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1648.0, Actividad Type: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1648.0, Actividad Walk: 10803 muestras
#    Duración total: 755.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 175.9s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1648.0, Actividad Workouts: 10804 muestras
#    Duración total: 625.5s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 45.8s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1648.0, Actividad Write: 3600 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1649.0, Actividad Eat: 18015 muestras
#    Duración total: 1090.7s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 77.2s)
#   ✅ Creadas 358 ventanas válidas
# 👤 Usuario 1649.0, Actividad Others: 10809 muestras
#    Duración total: 605.8s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 38.0s)
#   ✅ Creadas 213 ventanas válidas
# 👤 Usuario 1649.0, Actividad Sit: 3603 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1649.0, Actividad Stand: 3603 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1649.0, Actividad Type: 3603 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1649.0, Actividad Walk: 10811 muestras
#    Duración total: 649.9s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 80.0s)
#   ✅ Creadas 212 ventanas válidas
# 👤 Usuario 1649.0, Actividad Workouts: 11119 muestras
#    Duración total: 687.2s
#    ⚠️ Detectados 6 gaps > 1.0s (máximo: 56.7s)
#   ✅ Creadas 194 ventanas válidas
# 👤 Usuario 1649.0, Actividad Write: 3603 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1650.0, Actividad Eat: 18016 muestras
#    Duración total: 1072.7s
#    ⚠️ Detectados 4 gaps > 1.0s (máximo: 71.5s)
#   ✅ Creadas 357 ventanas válidas
# 👤 Usuario 1650.0, Actividad Others: 10802 muestras
#    Duración total: 610.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 41.1s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1650.0, Actividad Sit: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1650.0, Actividad Stand: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1650.0, Actividad Type: 3601 muestras
#    Duración total: 179.9s
#   ✅ Creadas 70 ventanas válidas
# 👤 Usuario 1650.0, Actividad Walk: 12570 muestras
#    Duración total: 675.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 71.6s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1650.0, Actividad Workouts: 10802 muestras
#    Duración total: 633.7s
#    ⚠️ Detectados 2 gaps > 1.0s (máximo: 59.5s)
#   ✅ Creadas 214 ventanas válidas
# 👤 Usuario 1650.0, Actividad Write: 3600 muestras
#    Duración total: 179.8s
#   ✅ Creadas 70 ventanas válidas
#
# 📊 RESUMEN DE VALIDACIÓN:
#   Ventanas intentadas: 457693
#   Ventanas creadas: 64754
#   Tasa de éxito: 14.1%
#
# 📊 RESULTADO FINAL (ROBUSTO):
#   Forma de X: (64754, 250, 3)
#   Forma de y: (64754,)
#   Total ventanas: 64754
#   Usuarios únicos: 51
#   Actividades únicas: ['Eat', 'Others', 'Sit', 'Stand', 'Type', 'Walk', 'Workouts', 'Write']
# 👥 Total de usuarios: 51
# 📊 Usuarios: [1600. 1601. 1602. 1603. 1604. 1605. 1606. 1607. 1608. 1609. 1610. 1611.
#  1612. 1613. 1614. 1615. 1616. 1617. 1618. 1619. 1620. 1621. 1622. 1623.
#  1624. 1625. 1626. 1627. 1628. 1629. 1630. 1631. 1632. 1633. 1634. 1635.
#  1636. 1637. 1638. 1639. 1640. 1641. 1642. 1643. 1644. 1645. 1646. 1647.
#  1648. 1649. 1650.]
# 📊 Forma de datos: (64754, 250, 3)
#
# 🔄 FOLD 1/51: Usuario de test = 1600.0
# --------------------------------------------------
# 📊 Train: 63476 ventanas de 50 usuarios
# 📊 Test: 1278 ventanas del usuario 1600.0
# 🎯 Clases comunes: 8
# 🏋️ Entrenando modelo...
# Epoch 1/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 434s 240ms/step - accuracy: 0.5840 - loss: 1.1240 - val_accuracy: 0.7089 - val_loss: 0.8030 - learning_rate: 0.0010
# Epoch 2/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 404s 226ms/step - accuracy: 0.6940 - loss: 0.8411 - val_accuracy: 0.7283 - val_loss: 0.6895 - learning_rate: 0.0010
# Epoch 3/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 407s 228ms/step - accuracy: 0.7481 - loss: 0.7141 - val_accuracy: 0.7519 - val_loss: 0.6825 - learning_rate: 0.0010
# Epoch 4/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 405s 227ms/step - accuracy: 0.7707 - loss: 0.6625 - val_accuracy: 0.8012 - val_loss: 0.5541 - learning_rate: 0.0010
# Epoch 5/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 411s 230ms/step - accuracy: 0.7933 - loss: 0.6027 - val_accuracy: 0.8077 - val_loss: 0.5555 - learning_rate: 0.0010
# Epoch 6/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 11314s 6s/step - accuracy: 0.8051 - loss: 0.5705 - val_accuracy: 0.8058 - val_loss: 0.5552 - learning_rate: 0.0010
# Epoch 7/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 421s 236ms/step - accuracy: 0.8172 - loss: 0.5365 - val_accuracy: 0.8204 - val_loss: 0.5172 - learning_rate: 0.0010
# Epoch 8/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 431s 241ms/step - accuracy: 0.8213 - loss: 0.5238 - val_accuracy: 0.8146 - val_loss: 0.4998 - learning_rate: 0.0010
# Epoch 9/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 436s 244ms/step - accuracy: 0.8287 - loss: 0.4985 - val_accuracy: 0.8318 - val_loss: 0.4621 - learning_rate: 0.0010
# Epoch 10/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 9238s 5s/step - accuracy: 0.8335 - loss: 0.4838 - val_accuracy: 0.8382 - val_loss: 0.4683 - learning_rate: 0.0010
# Epoch 11/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 454s 254ms/step - accuracy: 0.8389 - loss: 0.4689 - val_accuracy: 0.8566 - val_loss: 0.4276 - learning_rate: 0.0010
# Epoch 12/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 465s 261ms/step - accuracy: 0.8423 - loss: 0.4605 - val_accuracy: 0.8508 - val_loss: 0.4210 - learning_rate: 0.0010
# Epoch 13/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 476s 267ms/step - accuracy: 0.8413 - loss: 0.4582 - val_accuracy: 0.8601 - val_loss: 0.4154 - learning_rate: 0.0010
# Epoch 14/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 450s 252ms/step - accuracy: 0.8488 - loss: 0.4419 - val_accuracy: 0.8340 - val_loss: 0.4613 - learning_rate: 0.0010
# Epoch 15/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 452s 253ms/step - accuracy: 0.8491 - loss: 0.4377 - val_accuracy: 0.8406 - val_loss: 0.4717 - learning_rate: 0.0010
# Epoch 16/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 453s 254ms/step - accuracy: 0.8550 - loss: 0.4210 - val_accuracy: 0.8239 - val_loss: 0.4861 - learning_rate: 0.0010
# Epoch 17/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 452s 253ms/step - accuracy: 0.8520 - loss: 0.4298 - val_accuracy: 0.8423 - val_loss: 0.4589 - learning_rate: 0.0010
# Epoch 18/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 451s 252ms/step - accuracy: 0.8590 - loss: 0.4120 - val_accuracy: 0.8401 - val_loss: 0.4842 - learning_rate: 0.0010
# Epoch 19/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 450s 252ms/step - accuracy: 0.8588 - loss: 0.4127 - val_accuracy: 0.8415 - val_loss: 0.4665 - learning_rate: 0.0010
# Epoch 20/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 11329s 6s/step - accuracy: 0.8597 - loss: 0.4084 - val_accuracy: 0.8390 - val_loss: 0.4714 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 13.
# 🔍 Evaluando modelo...
# ✅ Usuario 1600.0: Accuracy = 0.9664
#
# 🔄 FOLD 2/51: Usuario de test = 1601.0
# --------------------------------------------------
# 📊 Train: 63479 ventanas de 50 usuarios
# 📊 Test: 1275 ventanas del usuario 1601.0
# 🎯 Clases comunes: 8
# 🏋️ Entrenando modelo...
# Epoch 1/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 549s 304ms/step - accuracy: 0.6042 - loss: 1.0861 - val_accuracy: 0.6482 - val_loss: 0.8719 - learning_rate: 0.0010
# Epoch 2/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 530s 297ms/step - accuracy: 0.7249 - loss: 0.7885 - val_accuracy: 0.7817 - val_loss: 0.6323 - learning_rate: 0.0010
# Epoch 3/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 11414s 6s/step - accuracy: 0.7708 - loss: 0.6736 - val_accuracy: 0.8253 - val_loss: 0.5183 - learning_rate: 0.0010
# Epoch 4/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 501s 281ms/step - accuracy: 0.7963 - loss: 0.6045 - val_accuracy: 0.8007 - val_loss: 0.5911 - learning_rate: 0.0010
# Epoch 5/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 514s 288ms/step - accuracy: 0.8037 - loss: 0.5816 - val_accuracy: 0.8199 - val_loss: 0.5139 - learning_rate: 0.0010
# Epoch 6/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 517s 290ms/step - accuracy: 0.8153 - loss: 0.5396 - val_accuracy: 0.8155 - val_loss: 0.5598 - learning_rate: 0.0010
# Epoch 7/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 11411s 6s/step - accuracy: 0.8267 - loss: 0.5128 - val_accuracy: 0.8140 - val_loss: 0.5332 - learning_rate: 0.0010
# Epoch 8/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.8333 - loss: 0.4894
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 516s 289ms/step - accuracy: 0.8353 - loss: 0.4868 - val_accuracy: 0.8362 - val_loss: 0.4800 - learning_rate: 0.0010
# Epoch 9/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 523s 293ms/step - accuracy: 0.8536 - loss: 0.4352 - val_accuracy: 0.8417 - val_loss: 0.4738 - learning_rate: 5.0000e-04
# Epoch 10/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 521s 292ms/step - accuracy: 0.8584 - loss: 0.4160 - val_accuracy: 0.8469 - val_loss: 0.4502 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 2012s 1s/step - accuracy: 0.8646 - loss: 0.3961 - val_accuracy: 0.8431 - val_loss: 0.4487 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 556s 312ms/step - accuracy: 0.8698 - loss: 0.3863 - val_accuracy: 0.8631 - val_loss: 0.4145 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 544s 305ms/step - accuracy: 0.8709 - loss: 0.3809 - val_accuracy: 0.8562 - val_loss: 0.4457 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1786/1786 ━━━━━━━━━━━━━━━━━━━━ 595s 333ms/step - accuracy: 0.8730 - loss: 0.3731 - val_accuracy: 0.8529 - val_loss: 0.4551 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1559/1786 ━━━━━━━━━━━━━━━━━━━━ 1:09 308ms/step - accuracy: 0.8756 - loss: 0.3678

# %%
print("🚀 Creando ventanas RAW de 250 timesteps...")

# Opción 1: Solo acelerómetro
X_accel_raw, y_accel_raw, subjects_accel, metadata_accel = create_raw_windows_250_timesteps(
    df=df_gyro,  # Tu DataFrame de acelerómetro
    window_seconds=5,
    overlap_percent=50,
    sampling_rate=20,
    target_timesteps=250
)

# Opción 2: Acelerómetro + Giroscopio (RECOMENDADO)
# X_multi_raw, y_multi_raw, subjects_multi, metadata_multi = create_raw_windows_multi_sensor(
#     df_accel=df_accel_inner,
#     df_gyro=df_gyro_inner,
#     window_seconds=5,
#     overlap_percent=50,
#     sampling_rate=20,
#     target_timesteps=250
# )

# Validar ventanas
validate_raw_windows(X_accel_raw, y_accel_raw, subjects_accel, metadata_accel)

# Preparar para entrenamiento
from sklearn.preprocessing import LabelEncoder

# Codificar etiquetas
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_accel_raw)

# División de datos
X_train, X_test, y_train, y_test = train_test_split(
    X_accel_raw, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

print(f"✅ Datos preparados:")
print(f"  X_train: {X_train.shape}")  # (n_samples, 250, 6)
print(f"  X_test: {X_test.shape}")
print(f"  Timesteps: {X_train.shape[1]}")
print(f"  Características: {X_train.shape[2]}")

# Crear y entrenar modelo
input_shape = (250, X_train.shape[2])  # (250, 6) para multi-sensor
num_classes = len(label_encoder.classes_)
# Out:
# 🚀 Creando ventanas RAW de 250 timesteps...
# 🔧 Configuración de ventanas RAW:
#   Duración: 5s
#   Timesteps objetivo: 250
#   Frecuencia de muestreo: 20Hz
#   Solapamiento: 50%
#   Muestras esperadas por ventana: 100
#   Paso entre ventanas: 50 muestras
# 👤 Usuario 1600.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad B: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad C: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad D: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad E: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad F: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad I: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad K: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad Q: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad R: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1600.0, Actividad S: 4175 muestras
#   ✅ Creadas 82 ventanas
# 👤 Usuario 1601.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad B: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad C: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad D: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad E: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad F: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad G: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad I: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad J: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad K: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad L: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad O: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad P: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1601.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad E: 3699 muestras
#   ✅ Creadas 72 ventanas
# 👤 Usuario 1602.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1602.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad B: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad E: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad F: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad G: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad I: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad J: 3619 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad K: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad M: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad O: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad P: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad R: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1603.0, Actividad S: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad C: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad F: 3617 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad I: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1604.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad D: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad E: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad F: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad G: 3615 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad I: 4935 muestras
#   ✅ Creadas 97 ventanas
# 👤 Usuario 1605.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad K: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad L: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad M: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad P: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad Q: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1605.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1606.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad B: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad D: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad E: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad F: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad G: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad I: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad J: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad K: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad L: 4577 muestras
#   ✅ Creadas 90 ventanas
# 👤 Usuario 1607.0, Actividad M: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad O: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad P: 3604 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad Q: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1607.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad H: 3609 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad J: 6899 muestras
#   ✅ Creadas 136 ventanas
# 👤 Usuario 1608.0, Actividad K: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad M: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad O: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad P: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad R: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1608.0, Actividad S: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad A: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad B: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad C: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad D: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad E: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad F: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad G: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad H: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad I: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad J: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad K: 6070 muestras
#   ✅ Creadas 120 ventanas
# 👤 Usuario 1609.0, Actividad L: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1609.0, Actividad M: 4053 muestras
#   ✅ Creadas 80 ventanas
# 👤 Usuario 1609.0, Actividad O: 4875 muestras
#   ✅ Creadas 96 ventanas
# 👤 Usuario 1609.0, Actividad P: 4191 muestras
#   ✅ Creadas 82 ventanas
# 👤 Usuario 1609.0, Actividad Q: 3603 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 
muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1643.0, Actividad L: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad M: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad O: 3611 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1643.0, Actividad P: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad R: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1643.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad C: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad D: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad E: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad H: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad K: 5870 muestras
#   ✅ Creadas 116 ventanas
# 👤 Usuario 1644.0, Actividad L: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad O: 5502 muestras
#   ✅ Creadas 109 ventanas
# 👤 Usuario 1644.0, Actividad P: 4977 muestras
#   ✅ Creadas 98 ventanas
# 👤 Usuario 1644.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad R: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1644.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad C: 5763 muestras
#   ✅ Creadas 114 ventanas
# 👤 Usuario 1645.0, Actividad D: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad E: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad G: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad H: 4307 muestras
#   ✅ Creadas 85 ventanas
# 👤 Usuario 1645.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad K: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad L: 3613 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1645.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad P: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad R: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1645.0, Actividad S: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad C: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1646.0, Actividad D: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad E: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad H: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad K: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad L: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad P: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad R: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1646.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1647.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad B: 4272 muestras
#   ✅ Creadas 84 ventanas
# 👤 Usuario 1647.0, Actividad C: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad D: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad E: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad F: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad G: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad H: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad I: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad J: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad K: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad L: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad M: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad O: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad P: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1647.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad A: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad B: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad C: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad D: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad E: 3613 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad F: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad G: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad H: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad K: 3608 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad L: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad P: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1648.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad R: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1648.0, Actividad S: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1649.0, Actividad A: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad B: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad C: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad D: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad E: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad F: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad G: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad H: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad I: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad J: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad K: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad L: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad M: 3912 muestras
#   ✅ Creadas 77 ventanas
# 👤 Usuario 1649.0, Actividad O: 3600 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad P: 3602 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad Q: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad R: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1649.0, Actividad S: 3601 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1650.0, Actividad A: 5365 muestras
#   ✅ Creadas 106 ventanas
# 👤 Usuario 1650.0, Actividad B: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad C: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad D: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad E: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad F: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad G: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad H: 3613 muestras
#   ✅ Creadas 71 ventanas
# 👤 Usuario 1650.0, Actividad I: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad J: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad K: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad L: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad M: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad O: 3599 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad P: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad Q: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad R: 3598 muestras
#   ✅ Creadas 70 ventanas
# 👤 Usuario 1650.0, Actividad S: 3599 muestras
#   ✅ Creadas 70 ventanas
#
# 📊 RESULTADO FINAL:
#   Forma de X: (67705, 250, 3)
#   Forma de y: (67705,)
#   Total ventanas: 67705
#   Usuarios únicos: 51
#   Actividades únicas: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'O', 'P', 'Q', 'R', 'S']
# 🔍 VALIDANDO VENTANAS RAW
# ========================================
# ✅ Forma de X: (67705, 250, 3)
# ✅ Timesteps por ventana: 250
# ✅ Características por timestep: 3
# ✅ Total ventanas: 67705
# ✅ Timesteps correctos: 250
#
# 📊 Distribución de actividades:
#   A: 3790 ventanas
#   B: 3696 ventanas
#   C: 3553 ventanas
#   D: 3838 ventanas
#   E: 3820 ventanas
#   F: 3683 ventanas
#   G: 3753 ventanas
#   H: 3681 ventanas
#   I: 3780 ventanas
#   J: 3730 ventanas
#   K: 3898 ventanas
#   L: 3743 ventanas
#   M: 3768 ventanas
#   O: 3695 ventanas
#   P: 3835 ventanas
#   Q: 3885 ventanas
#   R: 3753 ventanas
#   S: 3804 ventanas
#
# 📈 Rango de valores:
#   Min: -34.900
#   Max: 34.904
#   Mean: -0.014
#   Std: 1.413
# ✅ Sin valores NaN
# ✅ Datos preparados:
#   X_train: (54164, 250, 3)
#   X_test: (13541, 250, 3)
#   Timesteps: 250
#   Características: 3

# %%
model = create_cnn_lstm_model(input_shape=input_shape, num_classes=num_classes)

# Entrenar
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    callbacks=callbacks
)
